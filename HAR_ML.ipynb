# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Extracing features from text file to list

features = []
with open(r'C:\Users\adity\har\features.txt') as f:
    for line in f:
        currlabel = line.split()[1]
        print(f'{currlabel} is appending')
        features.append(currlabel)

print(features)
# Out:
# tBodyAcc-mean()-X is appending
# tBodyAcc-mean()-Y is appending
# tBodyAcc-mean()-Z is appending
# tBodyAcc-std()-X is appending
# tBodyAcc-std()-Y is appending
# tBodyAcc-std()-Z is appending
# tBodyAcc-mad()-X is appending
# tBodyAcc-mad()-Y is appending
# tBodyAcc-mad()-Z is appending
# tBodyAcc-max()-X is appending
# tBodyAcc-max()-Y is appending
# tBodyAcc-max()-Z is appending
# tBodyAcc-min()-X is appending
# tBodyAcc-min()-Y is appending
# tBodyAcc-min()-Z is appending
# tBodyAcc-sma() is appending
# tBodyAcc-energy()-X is appending
# tBodyAcc-energy()-Y is appending
# tBodyAcc-energy()-Z is appending
# tBodyAcc-iqr()-X is appending
# tBodyAcc-iqr()-Y is appending
# tBodyAcc-iqr()-Z is appending
# tBodyAcc-entropy()-X is appending
# tBodyAcc-entropy()-Y is appending
# tBodyAcc-entropy()-Z is appending
# tBodyAcc-arCoeff()-X,1 is appending
# tBodyAcc-arCoeff()-X,2 is appending
# tBodyAcc-arCoeff()-X,3 is appending
# tBodyAcc-arCoeff()-X,4 is appending
# tBodyAcc-arCoeff()-Y,1 is appending
# tBodyAcc-arCoeff()-Y,2 is appending
# tBodyAcc-arCoeff()-Y,3 is appending
# tBodyAcc-arCoeff()-Y,4 is appending
# tBodyAcc-arCoeff()-Z,1 is appending
# tBodyAcc-arCoeff()-Z,2 is appending
# tBodyAcc-arCoeff()-Z,3 is appending
# tBodyAcc-arCoeff()-Z,4 is appending
# tBodyAcc-correlation()-X,Y is appending
# tBodyAcc-correlation()-X,Z is appending
# tBodyAcc-correlation()-Y,Z is appending
# tGravityAcc-mean()-X is appending
# tGravityAcc-mean()-Y is appending
# tGravityAcc-mean()-Z is appending
# tGravityAcc-std()-X is appending
# tGravityAcc-std()-Y is appending
# tGravityAcc-std()-Z is appending
# tGravityAcc-mad()-X is appending
# tGravityAcc-mad()-Y is appending
# tGravityAcc-mad()-Z is appending
# tGravityAcc-max()-X is appending
# tGravityAcc-max()-Y is appending
# tGravityAcc-max()-Z is appending
# tGravityAcc-min()-X is appending
# tGravityAcc-min()-Y is appending
# tGravityAcc-min()-Z is appending
# tGravityAcc-sma() is appending
# tGravityAcc-energy()-X is appending
# tGravityAcc-energy()-Y is appending
# tGravityAcc-energy()-Z is appending
# tGravityAcc-iqr()-X is appending
# tGravityAcc-iqr()-Y is appending
# tGravityAcc-iqr()-Z is appending
# tGravityAcc-entropy()-X is appending
# tGravityAcc-entropy()-Y is appending
# tGravityAcc-entropy()-Z is appending
# tGravityAcc-arCoeff()-X,1 is appending
# tGravityAcc-arCoeff()-X,2 is appending
# tGravityAcc-arCoeff()-X,3 is appending
# tGravityAcc-arCoeff()-X,4 is appending
# tGravityAcc-arCoeff()-Y,1 is appending
# tGravityAcc-arCoeff()-Y,2 is appending
# tGravityAcc-arCoeff()-Y,3 is appending
# tGravityAcc-arCoeff()-Y,4 is appending
# tGravityAcc-arCoeff()-Z,1 is appending
# tGravityAcc-arCoeff()-Z,2 is appending
# tGravityAcc-arCoeff()-Z,3 is appending
# tGravityAcc-arCoeff()-Z,4 is appending
# tGravityAcc-correlation()-X,Y is appending
# tGravityAcc-correlation()-X,Z is appending
# tGravityAcc-correlation()-Y,Z is appending
# tBodyAccJerk-mean()-X is appending
# tBodyAccJerk-mean()-Y is appending
# tBodyAccJerk-mean()-Z is appending
# tBodyAccJerk-std()-X is appending
# tBodyAccJerk-std()-Y is appending
# tBodyAccJerk-std()-Z is appending
# tBodyAccJerk-mad()-X is appending
# tBodyAccJerk-mad()-Y is appending
# tBodyAccJerk-mad()-Z is appending
# tBodyAccJerk-max()-X is appending
# tBodyAccJerk-max()-Y is appending
# tBodyAccJerk-max()-Z is appending
# tBodyAccJerk-min()-X is appending
# tBodyAccJerk-min()-Y is appending
# tBodyAccJerk-min()-Z is appending
# tBodyAccJerk-sma() is appending
# tBodyAccJerk-energy()-X is appending
# tBodyAccJerk-energy()-Y is appending
# tBodyAccJerk-energy()-Z is appending
# tBodyAccJerk-iqr()-X is appending
# tBodyAccJerk-iqr()-Y is appending
# tBodyAccJerk-iqr()-Z is appending
# tBodyAccJerk-entropy()-X is appending
# tBodyAccJerk-entropy()-Y is appending
# tBodyAccJerk-entropy()-Z is appending
# tBodyAccJerk-arCoeff()-X,1 is appending
# tBodyAccJerk-arCoeff()-X,2 is appending
# tBodyAccJerk-arCoeff()-X,3 is appending
# tBodyAccJerk-arCoeff()-X,4 is appending
# tBodyAccJerk-arCoeff()-Y,1 is appending
# tBodyAccJerk-arCoeff()-Y,2 is appending
# tBodyAccJerk-arCoeff()-Y,3 is appending
# tBodyAccJerk-arCoeff()-Y,4 is appending
# tBodyAccJerk-arCoeff()-Z,1 is appending
# tBodyAccJerk-arCoeff()-Z,2 is appending
# tBodyAccJerk-arCoeff()-Z,3 is appending
# tBodyAccJerk-arCoeff()-Z,4 is appending
# tBodyAccJerk-correlation()-X,Y is appending
# tBodyAccJerk-correlation()-X,Z is appending
# tBodyAccJerk-correlation()-Y,Z is appending
# tBodyGyro-mean()-X is appending
# tBodyGyro-mean()-Y is appending
# tBodyGyro-mean()-Z is appending
# tBodyGyro-std()-X is appending
# tBodyGyro-std()-Y is appending
# tBodyGyro-std()-Z is appending
# tBodyGyro-mad()-X is appending
# tBodyGyro-mad()-Y is appending
# tBodyGyro-mad()-Z is appending
# tBodyGyro-max()-X is appending
# tBodyGyro-max()-Y is appending
# tBodyGyro-max()-Z is appending
# tBodyGyro-min()-X is appending
# tBodyGyro-min()-Y is appending
# tBodyGyro-min()-Z is appending
# tBodyGyro-sma() is appending
# tBodyGyro-energy()-X is appending
# tBodyGyro-energy()-Y is appending
# tBodyGyro-energy()-Z is appending
# tBodyGyro-iqr()-X is appending
# tBodyGyro-iqr()-Y is appending
# tBodyGyro-iqr()-Z is appending
# tBodyGyro-entropy()-X is appending
# tBodyGyro-entropy()-Y is appending
# tBodyGyro-entropy()-Z is appending
# tBodyGyro-arCoeff()-X,1 is appending
# tBodyGyro-arCoeff()-X,2 is appending
# tBodyGyro-arCoeff()-X,3 is appending
# tBodyGyro-arCoeff()-X,4 is appending
# tBodyGyro-arCoeff()-Y,1 is appending
# tBodyGyro-arCoeff()-Y,2 is appending
# tBodyGyro-arCoeff()-Y,3 is appending
# tBodyGyro-arCoeff()-Y,4 is appending
# tBodyGyro-arCoeff()-Z,1 is appending
# tBodyGyro-arCoeff()-Z,2 is appending
# tBodyGyro-arCoeff()-Z,3 is appending
# tBodyGyro-arCoeff()-Z,4 is appending
# tBodyGyro-correlation()-X,Y is appending
# tBodyGyro-correlation()-X,Z is appending
# tBodyGyro-correlation()-Y,Z is appending
# tBodyGyroJerk-mean()-X is appending
# tBodyGyroJerk-mean()-Y is appending
# tBodyGyroJerk-mean()-Z is appending
# tBodyGyroJerk-std()-X is appending
# tBodyGyroJerk-std()-Y is appending
# tBodyGyroJerk-std()-Z is appending
# tBodyGyroJerk-mad()-X is appending
# tBodyGyroJerk-mad()-Y is appending
# tBodyGyroJerk-mad()-Z is appending
# tBodyGyroJerk-max()-X is appending
# tBodyGyroJerk-max()-Y is appending
# tBodyGyroJerk-max()-Z is appending
# tBodyGyroJerk-min()-X is appending
# tBodyGyroJerk-min()-Y is appending
# tBodyGyroJerk-min()-Z is appending
# tBodyGyroJerk-sma() is appending
# tBodyGyroJerk-energy()-X is appending
# tBodyGyroJerk-energy()-Y is appending
# tBodyGyroJerk-energy()-Z is appending
# tBodyGyroJerk-iqr()-X is appending
# tBodyGyroJerk-iqr()-Y is appending
# tBodyGyroJerk-iqr()-Z is appending
# tBodyGyroJerk-entropy()-X is appending
# tBodyGyroJerk-entropy()-Y is appending
# tBodyGyroJerk-entropy()-Z is appending
# tBodyGyroJerk-arCoeff()-X,1 is appending
# tBodyGyroJerk-arCoeff()-X,2 is appending
# tBodyGyroJerk-arCoeff()-X,3 is appending
# tBodyGyroJerk-arCoeff()-X,4 is appending
# tBodyGyroJerk-arCoeff()-Y,1 is appending
# tBodyGyroJerk-arCoeff()-Y,2 is appending
# tBodyGyroJerk-arCoeff()-Y,3 is appending
# tBodyGyroJerk-arCoeff()-Y,4 is appending
# tBodyGyroJerk-arCoeff()-Z,1 is appending
# tBodyGyroJerk-arCoeff()-Z,2 is appending
# tBodyGyroJerk-arCoeff()-Z,3 is appending
# tBodyGyroJerk-arCoeff()-Z,4 is appending
# tBodyGyroJerk-correlation()-X,Y is appending
# tBodyGyroJerk-correlation()-X,Z is appending
# tBodyGyroJerk-correlation()-Y,Z is appending
# tBodyAccMag-mean() is appending
# tBodyAccMag-std() is appending
# tBodyAccMag-mad() is appending
# tBodyAccMag-max() is appending
# tBodyAccMag-min() is appending
# tBodyAccMag-sma() is appending
# tBodyAccMag-energy() is appending
# tBodyAccMag-iqr() is appending
# tBodyAccMag-entropy() is appending
# tBodyAccMag-arCoeff()1 is appending
# tBodyAccMag-arCoeff()2 is appending
# tBodyAccMag-arCoeff()3 is appending
# tBodyAccMag-arCoeff()4 is appending
# tGravityAccMag-mean() is appending
# tGravityAccMag-std() is appending
# tGravityAccMag-mad() is appending
# tGravityAccMag-max() is appending
# tGravityAccMag-min() is appending
# tGravityAccMag-sma() is appending
# tGravityAccMag-energy() is appending
# tGravityAccMag-iqr() is appending
# tGravityAccMag-entropy() is appending
# tGravityAccMag-arCoeff()1 is appending
# tGravityAccMag-arCoeff()2 is appending
# tGravityAccMag-arCoeff()3 is appending
# tGravityAccMag-arCoeff()4 is appending
# tBodyAccJerkMag-mean() is appending
# tBodyAccJerkMag-std() is appending
# tBodyAccJerkMag-mad() is appending
# tBodyAccJerkMag-max() is appending
# tBodyAccJerkMag-min() is appending
# tBodyAccJerkMag-sma() is appending
# tBodyAccJerkMag-energy() is appending
# tBodyAccJerkMag-iqr() is appending
# tBodyAccJerkMag-entropy() is appending
# tBodyAccJerkMag-arCoeff()1 is appending
# tBodyAccJerkMag-arCoeff()2 is appending
# tBodyAccJerkMag-arCoeff()3 is appending
# tBodyAccJerkMag-arCoeff()4 is appending
# tBodyGyroMag-mean() is appending
# tBodyGyroMag-std() is appending
# tBodyGyroMag-mad() is appending
# tBodyGyroMag-max() is appending
# tBodyGyroMag-min() is appending
# tBodyGyroMag-sma() is appending
# tBodyGyroMag-energy() is appending
# tBodyGyroMag-iqr() is appending
# tBodyGyroMag-entropy() is appending
# tBodyGyroMag-arCoeff()1 is appending
# tBodyGyroMag-arCoeff()2 is appending
# tBodyGyroMag-arCoeff()3 is appending
# tBodyGyroMag-arCoeff()4 is appending
# tBodyGyroJerkMag-mean() is appending
# tBodyGyroJerkMag-std() is appending
# tBodyGyroJerkMag-mad() is appending
# tBodyGyroJerkMag-max() is appending
# tBodyGyroJerkMag-min() is appending
# tBodyGyroJerkMag-sma() is appending
# tBodyGyroJerkMag-energy() is appending
# tBodyGyroJerkMag-iqr() is appending
# tBodyGyroJerkMag-entropy() is appending
# tBodyGyroJerkMag-arCoeff()1 is appending
# tBodyGyroJerkMag-arCoeff()2 is appending
# tBodyGyroJerkMag-arCoeff()3 is appending
# tBodyGyroJerkMag-arCoeff()4 is appending
# fBodyAcc-mean()-X is appending
# fBodyAcc-mean()-Y is appending
# fBodyAcc-mean()-Z is appending
# fBodyAcc-std()-X is appending
# fBodyAcc-std()-Y is appending
# fBodyAcc-std()-Z is appending
# fBodyAcc-mad()-X is appending
# fBodyAcc-mad()-Y is appending
# fBodyAcc-mad()-Z is appending
# fBodyAcc-max()-X is appending
# fBodyAcc-max()-Y is appending
# fBodyAcc-max()-Z is appending
# fBodyAcc-min()-X is appending
# fBodyAcc-min()-Y is appending
# fBodyAcc-min()-Z is appending
# fBodyAcc-sma() is appending
# fBodyAcc-energy()-X is appending
# fBodyAcc-energy()-Y is appending
# fBodyAcc-energy()-Z is appending
# fBodyAcc-iqr()-X is appending
# fBodyAcc-iqr()-Y is appending
# fBodyAcc-iqr()-Z is appending
# fBodyAcc-entropy()-X is appending
# fBodyAcc-entropy()-Y is appending
# fBodyAcc-entropy()-Z is appending
# fBodyAcc-maxInds-X is appending
# fBodyAcc-maxInds-Y is appending
# fBodyAcc-maxInds-Z is appending
# fBodyAcc-meanFreq()-X is appending
# fBodyAcc-meanFreq()-Y is appending
# fBodyAcc-meanFreq()-Z is appending
# fBodyAcc-skewness()-X is appending
# fBodyAcc-kurtosis()-X is appending
# fBodyAcc-skewness()-Y is appending
# fBodyAcc-kurtosis()-Y is appending
# fBodyAcc-skewness()-Z is appending
# fBodyAcc-kurtosis()-Z is appending
# fBodyAcc-bandsEnergy()-1,8 is appending
# fBodyAcc-bandsEnergy()-9,16 is appending
# fBodyAcc-bandsEnergy()-17,24 is appending
# fBodyAcc-bandsEnergy()-25,32 is appending
# fBodyAcc-bandsEnergy()-33,40 is appending
# fBodyAcc-bandsEnergy()-41,48 is appending
# fBodyAcc-bandsEnergy()-49,56 is appending
# fBodyAcc-bandsEnergy()-57,64 is appending
# fBodyAcc-bandsEnergy()-1,16 is appending
# fBodyAcc-bandsEnergy()-17,32 is appending
# fBodyAcc-bandsEnergy()-33,48 is appending
# fBodyAcc-bandsEnergy()-49,64 is appending
# fBodyAcc-bandsEnergy()-1,24 is appending
# fBodyAcc-bandsEnergy()-25,48 is appending
# fBodyAcc-bandsEnergy()-1,8 is appending
# fBodyAcc-bandsEnergy()-9,16 is appending
# fBodyAcc-bandsEnergy()-17,24 is appending
# fBodyAcc-bandsEnergy()-25,32 is appending
# fBodyAcc-bandsEnergy()-33,40 is appending
# fBodyAcc-bandsEnergy()-41,48 is appending
# fBodyAcc-bandsEnergy()-49,56 is appending
# fBodyAcc-bandsEnergy()-57,64 is appending
# fBodyAcc-bandsEnergy()-1,16 is appending
# fBodyAcc-bandsEnergy()-17,32 is appending
# fBodyAcc-bandsEnergy()-33,48 is appending
# fBodyAcc-bandsEnergy()-49,64 is appending
# fBodyAcc-bandsEnergy()-1,24 is appending
# fBodyAcc-bandsEnergy()-25,48 is appending
# fBodyAcc-bandsEnergy()-1,8 is appending
# fBodyAcc-bandsEnergy()-9,16 is appending
# fBodyAcc-bandsEnergy()-17,24 is appending
# fBodyAcc-bandsEnergy()-25,32 is appending
# fBodyAcc-bandsEnergy()-33,40 is appending
# fBodyAcc-bandsEnergy()-41,48 is appending
# fBodyAcc-bandsEnergy()-49,56 is appending
# fBodyAcc-bandsEnergy()-57,64 is appending
# fBodyAcc-bandsEnergy()-1,16 is appending
# fBodyAcc-bandsEnergy()-17,32 is appending
# fBodyAcc-bandsEnergy()-33,48 is appending
# fBodyAcc-bandsEnergy()-49,64 is appending
# fBodyAcc-bandsEnergy()-1,24 is appending
# fBodyAcc-bandsEnergy()-25,48 is appending
# fBodyAccJerk-mean()-X is appending
# fBodyAccJerk-mean()-Y is appending
# fBodyAccJerk-mean()-Z is appending
# fBodyAccJerk-std()-X is appending
# fBodyAccJerk-std()-Y is appending
# fBodyAccJerk-std()-Z is appending
# fBodyAccJerk-mad()-X is appending
# fBodyAccJerk-mad()-Y is appending
# fBodyAccJerk-mad()-Z is appending
# fBodyAccJerk-max()-X is appending
# fBodyAccJerk-max()-Y is appending
# fBodyAccJerk-max()-Z is appending
# fBodyAccJerk-min()-X is appending
# fBodyAccJerk-min()-Y is appending
# fBodyAccJerk-min()-Z is appending
# fBodyAccJerk-sma() is appending
# fBodyAccJerk-energy()-X is appending
# fBodyAccJerk-energy()-Y is appending
# fBodyAccJerk-energy()-Z is appending
# fBodyAccJerk-iqr()-X is appending
# fBodyAccJerk-iqr()-Y is appending
# fBodyAccJerk-iqr()-Z is appending
# fBodyAccJerk-entropy()-X is appending
# fBodyAccJerk-entropy()-Y is appending
# fBodyAccJerk-entropy()-Z is appending
# fBodyAccJerk-maxInds-X is appending
# fBodyAccJerk-maxInds-Y is appending
# fBodyAccJerk-maxInds-Z is appending
# fBodyAccJerk-meanFreq()-X is appending
# fBodyAccJerk-meanFreq()-Y is appending
# fBodyAccJerk-meanFreq()-Z is appending
# fBodyAccJerk-skewness()-X is appending
# fBodyAccJerk-kurtosis()-X is appending
# fBodyAccJerk-skewness()-Y is appending
# fBodyAccJerk-kurtosis()-Y is appending
# fBodyAccJerk-skewness()-Z is appending
# fBodyAccJerk-kurtosis()-Z is appending
# fBodyAccJerk-bandsEnergy()-1,8 is appending
# fBodyAccJerk-bandsEnergy()-9,16 is appending
# fBodyAccJerk-bandsEnergy()-17,24 is appending
# fBodyAccJerk-bandsEnergy()-25,32 is appending
# fBodyAccJerk-bandsEnergy()-33,40 is appending
# fBodyAccJerk-bandsEnergy()-41,48 is appending
# fBodyAccJerk-bandsEnergy()-49,56 is appending
# fBodyAccJerk-bandsEnergy()-57,64 is appending
# fBodyAccJerk-bandsEnergy()-1,16 is appending
# fBodyAccJerk-bandsEnergy()-17,32 is appending
# fBodyAccJerk-bandsEnergy()-33,48 is appending
# fBodyAccJerk-bandsEnergy()-49,64 is appending
# fBodyAccJerk-bandsEnergy()-1,24 is appending
# fBodyAccJerk-bandsEnergy()-25,48 is appending
# fBodyAccJerk-bandsEnergy()-1,8 is appending
# fBodyAccJerk-bandsEnergy()-9,16 is appending
# fBodyAccJerk-bandsEnergy()-17,24 is appending
# fBodyAccJerk-bandsEnergy()-25,32 is appending
# fBodyAccJerk-bandsEnergy()-33,40 is appending
# fBodyAccJerk-bandsEnergy()-41,48 is appending
# fBodyAccJerk-bandsEnergy()-49,56 is appending
# fBodyAccJerk-bandsEnergy()-57,64 is appending
# fBodyAccJerk-bandsEnergy()-1,16 is appending
# fBodyAccJerk-bandsEnergy()-17,32 is appending
# fBodyAccJerk-bandsEnergy()-33,48 is appending
# fBodyAccJerk-bandsEnergy()-49,64 is appending
# fBodyAccJerk-bandsEnergy()-1,24 is appending
# fBodyAccJerk-bandsEnergy()-25,48 is appending
# fBodyAccJerk-bandsEnergy()-1,8 is appending
# fBodyAccJerk-bandsEnergy()-9,16 is appending
# fBodyAccJerk-bandsEnergy()-17,24 is appending
# fBodyAccJerk-bandsEnergy()-25,32 is appending
# fBodyAccJerk-bandsEnergy()-33,40 is appending
# fBodyAccJerk-bandsEnergy()-41,48 is appending
# fBodyAccJerk-bandsEnergy()-49,56 is appending
# fBodyAccJerk-bandsEnergy()-57,64 is appending
# fBodyAccJerk-bandsEnergy()-1,16 is appending
# fBodyAccJerk-bandsEnergy()-17,32 is appending
# fBodyAccJerk-bandsEnergy()-33,48 is appending
# fBodyAccJerk-bandsEnergy()-49,64 is appending
# fBodyAccJerk-bandsEnergy()-1,24 is appending
# fBodyAccJerk-bandsEnergy()-25,48 is appending
# fBodyGyro-mean()-X is appending
# fBodyGyro-mean()-Y is appending
# fBodyGyro-mean()-Z is appending
# fBodyGyro-std()-X is appending
# fBodyGyro-std()-Y is appending
# fBodyGyro-std()-Z is appending
# fBodyGyro-mad()-X is appending
# fBodyGyro-mad()-Y is appending
# fBodyGyro-mad()-Z is appending
# fBodyGyro-max()-X is appending
# fBodyGyro-max()-Y is appending
# fBodyGyro-max()-Z is appending
# fBodyGyro-min()-X is appending
# fBodyGyro-min()-Y is appending
# fBodyGyro-min()-Z is appending
# fBodyGyro-sma() is appending
# fBodyGyro-energy()-X is appending
# fBodyGyro-energy()-Y is appending
# fBodyGyro-energy()-Z is appending
# fBodyGyro-iqr()-X is appending
# fBodyGyro-iqr()-Y is appending
# fBodyGyro-iqr()-Z is appending
# fBodyGyro-entropy()-X is appending
# fBodyGyro-entropy()-Y is appending
# fBodyGyro-entropy()-Z is appending
# fBodyGyro-maxInds-X is appending
# fBodyGyro-maxInds-Y is appending
# fBodyGyro-maxInds-Z is appending
# fBodyGyro-meanFreq()-X is appending
# fBodyGyro-meanFreq()-Y is appending
# fBodyGyro-meanFreq()-Z is appending
# fBodyGyro-skewness()-X is appending
# fBodyGyro-kurtosis()-X is appending
# fBodyGyro-skewness()-Y is appending
# fBodyGyro-kurtosis()-Y is appending
# fBodyGyro-skewness()-Z is appending
# fBodyGyro-kurtosis()-Z is appending
# fBodyGyro-bandsEnergy()-1,8 is appending
# fBodyGyro-bandsEnergy()-9,16 is appending
# fBodyGyro-bandsEnergy()-17,24 is appending
# fBodyGyro-bandsEnergy()-25,32 is appending
# fBodyGyro-bandsEnergy()-33,40 is appending
# fBodyGyro-bandsEnergy()-41,48 is appending
# fBodyGyro-bandsEnergy()-49,56 is appending
# fBodyGyro-bandsEnergy()-57,64 is appending
# fBodyGyro-bandsEnergy()-1,16 is appending
# fBodyGyro-bandsEnergy()-17,32 is appending
# fBodyGyro-bandsEnergy()-33,48 is appending
# fBodyGyro-bandsEnergy()-49,64 is appending
# fBodyGyro-bandsEnergy()-1,24 is appending
# fBodyGyro-bandsEnergy()-25,48 is appending
# fBodyGyro-bandsEnergy()-1,8 is appending
# fBodyGyro-bandsEnergy()-9,16 is appending
# fBodyGyro-bandsEnergy()-17,24 is appending
# fBodyGyro-bandsEnergy()-25,32 is appending
# fBodyGyro-bandsEnergy()-33,40 is appending
# fBodyGyro-bandsEnergy()-41,48 is appending
# fBodyGyro-bandsEnergy()-49,56 is appending
# fBodyGyro-bandsEnergy()-57,64 is appending
# fBodyGyro-bandsEnergy()-1,16 is appending
# fBodyGyro-bandsEnergy()-17,32 is appending
# fBodyGyro-bandsEnergy()-33,48 is appending
# fBodyGyro-bandsEnergy()-49,64 is appending
# fBodyGyro-bandsEnergy()-1,24 is appending
# fBodyGyro-bandsEnergy()-25,48 is appending
# fBodyGyro-bandsEnergy()-1,8 is appending
# fBodyGyro-bandsEnergy()-9,16 is appending
# fBodyGyro-bandsEnergy()-17,24 is appending
# fBodyGyro-bandsEnergy()-25,32 is appending
# fBodyGyro-bandsEnergy()-33,40 is appending
# fBodyGyro-bandsEnergy()-41,48 is appending
# fBodyGyro-bandsEnergy()-49,56 is appending
# fBodyGyro-bandsEnergy()-57,64 is appending
# fBodyGyro-bandsEnergy()-1,16 is appending
# fBodyGyro-bandsEnergy()-17,32 is appending
# fBodyGyro-bandsEnergy()-33,48 is appending
# fBodyGyro-bandsEnergy()-49,64 is appending
# fBodyGyro-bandsEnergy()-1,24 is appending
# fBodyGyro-bandsEnergy()-25,48 is appending
# fBodyAccMag-mean() is appending
# fBodyAccMag-std() is appending
# fBodyAccMag-mad() is appending
# fBodyAccMag-max() is appending
# fBodyAccMag-min() is appending
# fBodyAccMag-sma() is appending
# fBodyAccMag-energy() is appending
# fBodyAccMag-iqr() is appending
# fBodyAccMag-entropy() is appending
# fBodyAccMag-maxInds is appending
# fBodyAccMag-meanFreq() is appending
# fBodyAccMag-skewness() is appending
# fBodyAccMag-kurtosis() is appending
# fBodyBodyAccJerkMag-mean() is appending
# fBodyBodyAccJerkMag-std() is appending
# fBodyBodyAccJerkMag-mad() is appending
# fBodyBodyAccJerkMag-max() is appending
# fBodyBodyAccJerkMag-min() is appending
# fBodyBodyAccJerkMag-sma() is appending
# fBodyBodyAccJerkMag-energy() is appending
# fBodyBodyAccJerkMag-iqr() is appending
# fBodyBodyAccJerkMag-entropy() is appending
# fBodyBodyAccJerkMag-maxInds is appending
# fBodyBodyAccJerkMag-meanFreq() is appending
# fBodyBodyAccJerkMag-skewness() is appending
# fBodyBodyAccJerkMag-kurtosis() is appending
# fBodyBodyGyroMag-mean() is appending
# fBodyBodyGyroMag-std() is appending
# fBodyBodyGyroMag-mad() is appending
# fBodyBodyGyroMag-max() is appending
# fBodyBodyGyroMag-min() is appending
# fBodyBodyGyroMag-sma() is appending
# fBodyBodyGyroMag-energy() is appending
# fBodyBodyGyroMag-iqr() is appending
# fBodyBodyGyroMag-entropy() is appending
# fBodyBodyGyroMag-maxInds is appending
# fBodyBodyGyroMag-meanFreq() is appending
# fBodyBodyGyroMag-skewness() is appending
# fBodyBodyGyroMag-kurtosis() is appending
# fBodyBodyGyroJerkMag-mean() is appending
# fBodyBodyGyroJerkMag-std() is appending
# fBodyBodyGyroJerkMag-mad() is appending
# fBodyBodyGyroJerkMag-max() is appending
# fBodyBodyGyroJerkMag-min() is appending
# fBodyBodyGyroJerkMag-sma() is appending
# fBodyBodyGyroJerkMag-energy() is appending
# fBodyBodyGyroJerkMag-iqr() is appending
# fBodyBodyGyroJerkMag-entropy() is appending
# fBodyBodyGyroJerkMag-maxInds is appending
# fBodyBodyGyroJerkMag-meanFreq() is appending
# fBodyBodyGyroJerkMag-skewness() is appending
# fBodyBodyGyroJerkMag-kurtosis() is appending
# angle(tBodyAccMean,gravity) is appending
# angle(tBodyAccJerkMean),gravityMean) is appending
# angle(tBodyGyroMean,gravityMean) is appending
# angle(tBodyGyroJerkMean,gravityMean) is appending
# angle(X,gravityMean) is appending
# angle(Y,gravityMean) is appending
# angle(Z,gravityMean) is appending
# ['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z', 'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z', 'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z', 'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z', 'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z', 'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-energy()-Y', 'tBodyAcc-energy()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y', 'tBodyAcc-iqr()-Z', 'tBodyAcc-entropy()-X', 'tBodyAcc-entropy()-Y', 'tBodyAcc-entropy()-Z', 'tBodyAcc-arCoeff()-X,1', 'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3', 'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1', 'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3', 'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1', 'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3', 'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y', 'tBodyAcc-correlation()-X,Z', 'tBodyAcc-correlation()-Y,Z', 'tGravityAcc-mean()-X', 'tGravityAcc-mean()-Y', 'tGravityAcc-mean()-Z', 'tGravityAcc-std()-X', 'tGravityAcc-std()-Y', 'tGravityAcc-std()-Z', 'tGravityAcc-mad()-X', 'tGravityAcc-mad()-Y', 'tGravityAcc-mad()-Z', 'tGravityAcc-max()-X', 'tGravityAcc-max()-Y', 'tGravityAcc-max()-Z', 'tGravityAcc-min()-X', 'tGravityAcc-min()-Y', 'tGravityAcc-min()-Z', 'tGravityAcc-sma()', 'tGravityAcc-energy()-X', 'tGravityAcc-energy()-Y', 'tGravityAcc-energy()-Z', 'tGravityAcc-iqr()-X', 'tGravityAcc-iqr()-Y', 'tGravityAcc-iqr()-Z', 'tGravityAcc-entropy()-X', 'tGravityAcc-entropy()-Y', 'tGravityAcc-entropy()-Z', 'tGravityAcc-arCoeff()-X,1', 'tGravityAcc-arCoeff()-X,2', 'tGravityAcc-arCoeff()-X,3', 'tGravityAcc-arCoeff()-X,4', 'tGravityAcc-arCoeff()-Y,1', 'tGravityAcc-arCoeff()-Y,2', 'tGravityAcc-arCoeff()-Y,3', 'tGravityAcc-arCoeff()-Y,4', 'tGravityAcc-arCoeff()-Z,1', 'tGravityAcc-arCoeff()-Z,2', 'tGravityAcc-arCoeff()-Z,3', 'tGravityAcc-arCoeff()-Z,4', 'tGravityAcc-correlation()-X,Y', 'tGravityAcc-correlation()-X,Z', 'tGravityAcc-correlation()-Y,Z', 'tBodyAccJerk-mean()-X', 'tBodyAccJerk-mean()-Y', 'tBodyAccJerk-mean()-Z', 'tBodyAccJerk-std()-X', 'tBodyAccJerk-std()-Y', 'tBodyAccJerk-std()-Z', 'tBodyAccJerk-mad()-X', 'tBodyAccJerk-mad()-Y', 'tBodyAccJerk-mad()-Z', 'tBodyAccJerk-max()-X', 'tBodyAccJerk-max()-Y', 'tBodyAccJerk-max()-Z', 'tBodyAccJerk-min()-X', 'tBodyAccJerk-min()-Y', 'tBodyAccJerk-min()-Z', 'tBodyAccJerk-sma()', 'tBodyAccJerk-energy()-X', 'tBodyAccJerk-energy()-Y', 'tBodyAccJerk-energy()-Z', 'tBodyAccJerk-iqr()-X', 'tBodyAccJerk-iqr()-Y', 'tBodyAccJerk-iqr()-Z', 'tBodyAccJerk-entropy()-X', 'tBodyAccJerk-entropy()-Y', 'tBodyAccJerk-entropy()-Z', 'tBodyAccJerk-arCoeff()-X,1', 'tBodyAccJerk-arCoeff()-X,2', 'tBodyAccJerk-arCoeff()-X,3', 'tBodyAccJerk-arCoeff()-X,4', 'tBodyAccJerk-arCoeff()-Y,1', 'tBodyAccJerk-arCoeff()-Y,2', 'tBodyAccJerk-arCoeff()-Y,3', 'tBodyAccJerk-arCoeff()-Y,4', 'tBodyAccJerk-arCoeff()-Z,1', 'tBodyAccJerk-arCoeff()-Z,2', 'tBodyAccJerk-arCoeff()-Z,3', 'tBodyAccJerk-arCoeff()-Z,4', 'tBodyAccJerk-correlation()-X,Y', 'tBodyAccJerk-correlation()-X,Z', 'tBodyAccJerk-correlation()-Y,Z', 'tBodyGyro-mean()-X', 'tBodyGyro-mean()-Y', 'tBodyGyro-mean()-Z', 'tBodyGyro-std()-X', 'tBodyGyro-std()-Y', 'tBodyGyro-std()-Z', 'tBodyGyro-mad()-X', 'tBodyGyro-mad()-Y', 'tBodyGyro-mad()-Z', 'tBodyGyro-max()-X', 'tBodyGyro-max()-Y', 'tBodyGyro-max()-Z', 'tBodyGyro-min()-X', 'tBodyGyro-min()-Y', 'tBodyGyro-min()-Z', 'tBodyGyro-sma()', 'tBodyGyro-energy()-X', 'tBodyGyro-energy()-Y', 'tBodyGyro-energy()-Z', 'tBodyGyro-iqr()-X', 'tBodyGyro-iqr()-Y', 'tBodyGyro-iqr()-Z', 'tBodyGyro-entropy()-X', 'tBodyGyro-entropy()-Y', 'tBodyGyro-entropy()-Z', 'tBodyGyro-arCoeff()-X,1', 'tBodyGyro-arCoeff()-X,2', 'tBodyGyro-arCoeff()-X,3', 'tBodyGyro-arCoeff()-X,4', 'tBodyGyro-arCoeff()-Y,1', 'tBodyGyro-arCoeff()-Y,2', 'tBodyGyro-arCoeff()-Y,3', 'tBodyGyro-arCoeff()-Y,4', 'tBodyGyro-arCoeff()-Z,1', 'tBodyGyro-arCoeff()-Z,2', 'tBodyGyro-arCoeff()-Z,3', 'tBodyGyro-arCoeff()-Z,4', 'tBodyGyro-correlation()-X,Y', 'tBodyGyro-correlation()-X,Z', 'tBodyGyro-cor ...

# %%
#Just to verify with some samples
print(features[0:6])
# Out:
# ['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z', 'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z']

# %%
#Making dataframe of training set

traindf = pd.read_csv(r'C:\Users\adity\har\train\X_train.txt', delim_whitespace=True, header=None)
traindf.columns = [features]
#adding new column of subject id , to which subject[1-30] data is associated with. 
traindf['subjectid'] = pd.read_csv(r'C:\Users\adity\har\train\subject_train.txt', header=None)
#adding new column of activity from reding y_train file 
traindf['activity'] = pd.read_csv(r'C:\Users\adity\har\train\y_train.txt', header=None)

#Converting labels to designated numerical labels (kind of label encoding)
activity = np.array(traindf.loc[:,"activity"])
activityname = []

for i in range(len(activity)):
    if activity[i] == 1:
        activityname.append('WALKING')
    elif activity[i] == 2:
        activityname.append('WALKING_UPSTAIRS')
    elif activity[i] == 3:
        activityname.append('WALKING_DOWNSTAIRS')
    elif activity[i] == 4:
        activityname.append('SITTING')
    elif activity[i] == 5:
        activityname.append('STANDING')
    elif activity[i] == 6:
        activityname.append('LAYING')

traindf['activityname'] = np.array(activityname)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_17060\1540579168.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   traindf = pd.read_csv(r'C:\Users\adity\har\train\X_train.txt', delim_whitespace=True, header=None)

# %%
#just to verify whether we got right mapping for activity labels
print(traindf.loc[:,['activity','activityname']])
# Out:
#      activity      activityname
# 0           5          STANDING
# 1           5          STANDING
# 2           5          STANDING
# 3           5          STANDING
# 4           5          STANDING
# ...       ...               ...
# 7347        2  WALKING_UPSTAIRS
# 7348        2  WALKING_UPSTAIRS
# 7349        2  WALKING_UPSTAIRS
# 7350        2  WALKING_UPSTAIRS
# 7351        2  WALKING_UPSTAIRS
#
# [7352 rows x 2 columns]

# %%
traindf.head()
# Out:
#   tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0          0.288585         -0.020294         -0.132905        -0.995279
# 1          0.278419         -0.016411         -0.123520        -0.998245
# 2          0.279653         -0.019467         -0.113462        -0.995380
# 3          0.279174         -0.026201         -0.123283        -0.996091
# 4          0.276629         -0.016570         -0.115362        -0.998139
#
#   tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0        -0.983111        -0.913526        -0.995112        -0.983185
# 1        -0.975300        -0.960322        -0.998807        -0.974914
# 2        -0.967187        -0.978944        -0.996520        -0.963668
# 3        -0.983403        -0.990675        -0.997099        -0.982750
# 4        -0.980817        -0.990482        -0.998321        -0.979672
#
#   tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0        -0.923527        -0.934724  ...                   -0.112754
# 1        -0.957686        -0.943068  ...                    0.053477
# 2        -0.977469        -0.938692  ...                   -0.118559
# 3        -0.989302        -0.938692  ...                   -0.036788
# 4        -0.990441        -0.942469  ...                    0.123320
#
#   angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                             0.030400                        -0.464761
# 1                            -0.007435                        -0.732626
# 2                             0.177899                         0.100699
# 3                            -0.012892                         0.640011
# 4                             0.122542                         0.693578
#
#   angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                            -0.018446            -0.841247
# 1                             0.703511            -0.844788
# 2                             0.808529            -0.848933
# 3                            -0.485366            -0.848649
# 4                            -0.615971            -0.847865
#
#   angle(Y,gravityMean) angle(Z,gravityMean) subjectid activity activityname
# 0             0.179941            -0.058627         1        5     STANDING
# 1             0.180289            -0.054317         1        5     STANDING
# 2             0.180637            -0.049118         1        5     STANDING
# 3             0.181935            -0.047663         1        5     STANDING
# 4             0.185151            -0.043892         1        5     STANDING
#
# [5 rows x 564 columns]

# %%
#Rows & Columns in Dataframe 
traindf.shape
# Out:
# (7352, 564)

# %%
traindf.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Data columns (total 564 columns):
#  #    Column                                   Dtype
# ---   ------                                   -----
#  0    (tBodyAcc-mean()-X,)                     float64
#  1    (tBodyAcc-mean()-Y,)                     float64
#  2    (tBodyAcc-mean()-Z,)                     float64
#  3    (tBodyAcc-std()-X,)                      float64
#  4    (tBodyAcc-std()-Y,)                      float64
#  5    (tBodyAcc-std()-Z,)                      float64
#  6    (tBodyAcc-mad()-X,)                      float64
#  7    (tBodyAcc-mad()-Y,)                      float64
#  8    (tBodyAcc-mad()-Z,)                      float64
#  9    (tBodyAcc-max()-X,)                      float64
#  10   (tBodyAcc-max()-Y,)                      float64
#  11   (tBodyAcc-max()-Z,)                      float64
#  12   (tBodyAcc-min()-X,)                      float64
#  13   (tBodyAcc-min()-Y,)                      float64
#  14   (tBodyAcc-min()-Z,)                      float64
#  15   (tBodyAcc-sma(),)                        float64
#  16   (tBodyAcc-energy()-X,)                   float64
#  17   (tBodyAcc-energy()-Y,)                   float64
#  18   (tBodyAcc-energy()-Z,)                   float64
#  19   (tBodyAcc-iqr()-X,)                      float64
#  20   (tBodyAcc-iqr()-Y,)                      float64
#  21   (tBodyAcc-iqr()-Z,)                      float64
#  22   (tBodyAcc-entropy()-X,)                  float64
#  23   (tBodyAcc-entropy()-Y,)                  float64
#  24   (tBodyAcc-entropy()-Z,)                  float64
#  25   (tBodyAcc-arCoeff()-X,1,)                float64
#  26   (tBodyAcc-arCoeff()-X,2,)                float64
#  27   (tBodyAcc-arCoeff()-X,3,)                float64
#  28   (tBodyAcc-arCoeff()-X,4,)                float64
#  29   (tBodyAcc-arCoeff()-Y,1,)                float64
#  30   (tBodyAcc-arCoeff()-Y,2,)                float64
#  31   (tBodyAcc-arCoeff()-Y,3,)                float64
#  32   (tBodyAcc-arCoeff()-Y,4,)                float64
#  33   (tBodyAcc-arCoeff()-Z,1,)                float64
#  34   (tBodyAcc-arCoeff()-Z,2,)                float64
#  35   (tBodyAcc-arCoeff()-Z,3,)                float64
#  36   (tBodyAcc-arCoeff()-Z,4,)                float64
#  37   (tBodyAcc-correlation()-X,Y,)            float64
#  38   (tBodyAcc-correlation()-X,Z,)            float64
#  39   (tBodyAcc-correlation()-Y,Z,)            float64
#  40   (tGravityAcc-mean()-X,)                  float64
#  41   (tGravityAcc-mean()-Y,)                  float64
#  42   (tGravityAcc-mean()-Z,)                  float64
#  43   (tGravityAcc-std()-X,)                   float64
#  44   (tGravityAcc-std()-Y,)                   float64
#  45   (tGravityAcc-std()-Z,)                   float64
#  46   (tGravityAcc-mad()-X,)                   float64
#  47   (tGravityAcc-mad()-Y,)                   float64
#  48   (tGravityAcc-mad()-Z,)                   float64
#  49   (tGravityAcc-max()-X,)                   float64
#  50   (tGravityAcc-max()-Y,)                   float64
#  51   (tGravityAcc-max()-Z,)                   float64
#  52   (tGravityAcc-min()-X,)                   float64
#  53   (tGravityAcc-min()-Y,)                   float64
#  54   (tGravityAcc-min()-Z,)                   float64
#  55   (tGravityAcc-sma(),)                     float64
#  56   (tGravityAcc-energy()-X,)                float64
#  57   (tGravityAcc-energy()-Y,)                float64
#  58   (tGravityAcc-energy()-Z,)                float64
#  59   (tGravityAcc-iqr()-X,)                   float64
#  60   (tGravityAcc-iqr()-Y,)                   float64
#  61   (tGravityAcc-iqr()-Z,)                   float64
#  62   (tGravityAcc-entropy()-X,)               float64
#  63   (tGravityAcc-entropy()-Y,)               float64
#  64   (tGravityAcc-entropy()-Z,)               float64
#  65   (tGravityAcc-arCoeff()-X,1,)             float64
#  66   (tGravityAcc-arCoeff()-X,2,)             float64
#  67   (tGravityAcc-arCoeff()-X,3,)             float64
#  68   (tGravityAcc-arCoeff()-X,4,)             float64
#  69   (tGravityAcc-arCoeff()-Y,1,)             float64
#  70   (tGravityAcc-arCoeff()-Y,2,)             float64
#  71   (tGravityAcc-arCoeff()-Y,3,)             float64
#  72   (tGravityAcc-arCoeff()-Y,4,)             float64
#  73   (tGravityAcc-arCoeff()-Z,1,)             float64
#  74   (tGravityAcc-arCoeff()-Z,2,)             float64
#  75   (tGravityAcc-arCoeff()-Z,3,)             float64
#  76   (tGravityAcc-arCoeff()-Z,4,)             float64
#  77   (tGravityAcc-correlation()-X,Y,)         float64
#  78   (tGravityAcc-correlation()-X,Z,)         float64
#  79   (tGravityAcc-correlation()-Y,Z,)         float64
#  80   (tBodyAccJerk-mean()-X,)                 float64
#  81   (tBodyAccJerk-mean()-Y,)                 float64
#  82   (tBodyAccJerk-mean()-Z,)                 float64
#  83   (tBodyAccJerk-std()-X,)                  float64
#  84   (tBodyAccJerk-std()-Y,)                  float64
#  85   (tBodyAccJerk-std()-Z,)                  float64
#  86   (tBodyAccJerk-mad()-X,)                  float64
#  87   (tBodyAccJerk-mad()-Y,)                  float64
#  88   (tBodyAccJerk-mad()-Z,)                  float64
#  89   (tBodyAccJerk-max()-X,)                  float64
#  90   (tBodyAccJerk-max()-Y,)                  float64
#  91   (tBodyAccJerk-max()-Z,)                  float64
#  92   (tBodyAccJerk-min()-X,)                  float64
#  93   (tBodyAccJerk-min()-Y,)                  float64
#  94   (tBodyAccJerk-min()-Z,)                  float64
#  95   (tBodyAccJerk-sma(),)                    float64
#  96   (tBodyAccJerk-energy()-X,)               float64
#  97   (tBodyAccJerk-energy()-Y,)               float64
#  98   (tBodyAccJerk-energy()-Z,)               float64
#  99   (tBodyAccJerk-iqr()-X,)                  float64
#  100  (tBodyAccJerk-iqr()-Y,)                  float64
#  101  (tBodyAccJerk-iqr()-Z,)                  float64
#  102  (tBodyAccJerk-entropy()-X,)              float64
#  103  (tBodyAccJerk-entropy()-Y,)              float64
#  104  (tBodyAccJerk-entropy()-Z,)              float64
#  105  (tBodyAccJerk-arCoeff()-X,1,)            float64
#  106  (tBodyAccJerk-arCoeff()-X,2,)            float64
#  107  (tBodyAccJerk-arCoeff()-X,3,)            float64
#  108  (tBodyAccJerk-arCoeff()-X,4,)            float64
#  109  (tBodyAccJerk-arCoeff()-Y,1,)            float64
#  110  (tBodyAccJerk-arCoeff()-Y,2,)            float64
#  111  (tBodyAccJerk-arCoeff()-Y,3,)            float64
#  112  (tBodyAccJerk-arCoeff()-Y,4,)            float64
#  113  (tBodyAccJerk-arCoeff()-Z,1,)            float64
#  114  (tBodyAccJerk-arCoeff()-Z,2,)            float64
#  115  (tBodyAccJerk-arCoeff()-Z,3,)            float64
#  116  (tBodyAccJerk-arCoeff()-Z,4,)            float64
#  117  (tBodyAccJerk-correlation()-X,Y,)        float64
#  118  (tBodyAccJerk-correlation()-X,Z,)        float64
#  119  (tBodyAccJerk-correlation()-Y,Z,)        float64
#  120  (tBodyGyro-mean()-X,)                    float64
#  121  (tBodyGyro-mean()-Y,)                    float64
#  122  (tBodyGyro-mean()-Z,)                    float64
#  123  (tBodyGyro-std()-X,)                     float64
#  124  (tBodyGyro-std()-Y,)                     float64
#  125  (tBodyGyro-std()-Z,)                     float64
#  126  (tBodyGyro-mad()-X,)                     float64
#  127  (tBodyGyro-mad()-Y,)                     float64
#  128  (tBodyGyro-mad()-Z,)                     float64
#  129  (tBodyGyro-max()-X,)                     float64
#  130  (tBodyGyro-max()-Y,)                     float64
#  131  (tBodyGyro-max()-Z,)                     float64
#  132  (tBodyGyro-min()-X,)                     float64
#  133  (tBodyGyro-min()-Y,)                     float64
#  134  (tBodyGyro-min()-Z,)                     float64
#  135  (tBodyGyro-sma(),)                       float64
#  136  (tBodyGyro-energy()-X,)                  float64
#  137  (tBodyGyro-energy()-Y,)                  float64
#  138  (tBodyGyro-energy()-Z,)                  float64
#  139  (tBodyGyro-iqr()-X,)                     float64
#  140  (tBodyGyro-iqr()-Y,)                     float64
#  141  (tBodyGyro-iqr()-Z,)                     float64
#  142  (tBodyGyro-entropy()-X,)                 float64
#  143  (tBodyGyro-entropy()-Y,)                 float64
#  144  (tBodyGyro-entropy()-Z,)                 float64
#  145  (tBodyGyro-arCoeff()-X,1,)               float64
#  146  (tBodyGyro-arCoeff()-X,2,)               float64
#  147  (tBodyGyro-arCoeff()-X,3,)               float64
#  148  (tBodyGyro-arCoeff()-X,4,)               float64
#  149  (tBodyGyro-arCoeff()-Y,1,)               float64
#  150  (tBodyGyro-arCoeff()-Y,2,)               float64
#  151  (tBodyGyro-arCoeff()-Y,3,)               float64
#  152  (tBodyGyro-arCoeff()-Y,4,)               float64
#  153  (tBodyGyro-arCoeff()-Z,1,)               float64
#  154  (tBodyGyro-arCoeff()-Z,2,)               float64
#  155  (tBodyGyro-arCoeff()-Z,3,)               float64
#  156  (tBodyGyro-arCoeff()-Z,4,)               float64
#  157  (tBodyGyro-correlation()-X,Y,)           float64
#  158  (tBodyGyro-correlation()-X,Z,)           float64
#  159  (tBodyGyro-correlation()-Y,Z,)           float64
#  160  (tBodyGyroJerk-mean()-X,)                float64
#  161  (tBodyGyroJerk-mean()-Y,)                float64
#  162  (tBodyGyroJerk-mean()-Z,)                float64
#  163  (tBodyGyroJerk-std()-X,)                 float64
#  164  (tBodyGyroJerk-std()-Y,)                 float64
#  165  (tBodyGyroJerk-std()-Z,)                 float64
#  166  (tBodyGyroJerk-mad()-X,)                 float64
#  167  (tBodyGyroJerk-mad()-Y,)                 float64
#  168  (tBodyGyroJerk-mad()-Z,)                 float64
#  169  (tBodyGyroJerk-max()-X,)                 float64
#  170  (tBodyGyroJerk-max()-Y,)                 float64
#  171  (tBodyGyroJerk-max()-Z,)                 float64
#  172  (tBodyGyroJerk-min()-X,)                 float64
#  173  (tBodyGyroJerk-min()-Y,)                 float64
#  174  (tBodyGyroJerk-min()-Z,)                 float64
#  175  (tBodyGyroJerk-sma(),)                   float64
#  176  (tBodyGyroJerk-energy()-X,)              float64
#  177  (tBodyGyroJerk-energy()-Y,)              float64
#  178  (tBodyGyroJerk-energy()-Z,)              float64
#  179  (tBodyGyroJerk-iqr()-X,)                 float64
#  180  (tBodyGyroJerk-iqr()-Y,)                 float64
#  181  (tBodyGyroJerk-iqr()-Z,)                 float64
#  182  (tBodyGyroJerk-entropy()-X,)             float64
#  183  (tBodyGyroJerk-entropy()-Y,)             float64
#  184  (tBodyGyroJerk-entropy()-Z,)             float64
#  185  (tBodyGyroJerk-arCoeff()-X,1,)           float64
#  186  (tBodyGyroJerk-arCoeff()-X,2,)           float64
#  187  (tBodyGyroJerk-arCoeff()-X,3,)           float64
#  188  (tBodyGyroJerk-arCoeff()-X,4,)           float64
#  189  (tBodyGyroJerk-arCoeff()-Y,1,)           float64
#  190  (tBodyGyroJerk-arCoeff()-Y,2,)           float64
#  191  (tBodyGyroJerk-arCoeff()-Y,3,)           float64
#  192  (tBodyGyroJerk-arCoeff()-Y,4,)           float64
#  193  (tBodyGyroJerk-arCoeff()-Z,1,)           float64
#  194  (tBodyGyroJerk-arCoeff()-Z,2,)           float64
#  195  (tBodyGyroJerk-arCoeff()-Z,3,)           float64
#  196  (tBodyGyroJerk-arCoeff()-Z,4,)           float64
#  197  (tBodyGyroJerk-correlation()-X,Y,)       float64
#  198  (tBodyGyroJerk-correlation()-X,Z,)       float64
#  199  (tBodyGyroJerk-correlation()-Y,Z,)       float64
#  200  (tBodyAccMag-mean(),)                    float64
#  201  (tBodyAccMag-std(),)                     float64
#  202  (tBodyAccMag-mad(),)                     float64
#  203  (tBodyAccMag-max(),)                     float64
#  204  (tBodyAccMag-min(),)                     float64
#  205  (tBodyAccMag-sma(),)                     float64
#  206  (tBodyAccMag-energy(),)                  float64
#  207  (tBodyAccMag-iqr(),)                     float64
#  208  (tBodyAccMag-entropy(),)                 float64
#  209  (tBodyAccMag-arCoeff()1,)                float64
#  210  (tBodyAccMag-arCoeff()2,)                float64
#  211  (tBodyAccMag-arCoeff()3,)                float64
#  212  (tBodyAccMag-arCoeff()4,)                float64
#  213  (tGravityAccMag-mean(),)                 float64
#  214  (tGravityAccMag-std(),)                  float64
#  215  (tGravityAccMag-mad(),)                  float64
#  216  (tGravityAccMag-max(),)                  float64
#  217  (tGravityAccMag-min(),)                  float64
#  218  (tGravityAccMag-sma(),)                  float64
#  219  (tGravityAccMag-energy(),)               float64
#  220  (tGravityAccMag-iqr(),)                  float64
#  221  (tGravityAccMag-entropy(),)              float64
#  222  (tGravityAccMag-arCoeff()1,)             float64
#  223  (tGravityAccMag-arCoeff()2,)             float64
#  224  (tGravityAccMag-arCoeff()3,)             float64
#  225  (tGravityAccMag-arCoeff()4,)             float64
#  226  (tBodyAccJerkMag-mean(),)                float64
#  227  (tBodyAccJerkMag-std(),)                 float64
#  228  (tBodyAccJerkMag-mad(),)                 float64
#  229  (tBodyAccJerkMag-max(),)                 float64
#  230  (tBodyAccJerkMag-min(),)                 float64
#  231  (tBodyAccJerkMag-sma(),)                 float64
#  232  (tBodyAccJerkMag-energy(),)              float64
#  233  (tBodyAccJerkMag-iqr(),)                 float64
#  234  (tBodyAccJerkMag-entropy(),)             float64
#  235  (tBodyAccJerkMag-arCoeff()1,)            float64
#  236  (tBodyAccJerkMag-arCoeff()2,)            float64
#  237  (tBodyAccJerkMag-arCoeff()3,)            float64
#  238  (tBodyAccJerkMag-arCoeff()4,)            float64
#  239  (tBodyGyroMag-mean(),)                   float64
#  240  (tBodyGyroMag-std(),)                    float64
#  241  (tBodyGyroMag-mad(),)                    float64
#  242  (tBodyGyroMag-max(),)                    float64
#  243  (tBodyGyroMag-min(),)                    float64
#  244  (tBodyGyroMag-sma(),)                    float64
#  245  (tBodyGyroMag-energy(),)                 float64
#  246  (tBodyGyroMag-iqr(),)                    float64
#  247  (tBodyGyroMag-entropy(),)                float64
#  248  (tBodyGyroMag-arCoeff()1,)               float64
#  249  (tBodyGyroMag-arCoeff()2,)               float64
#  250  (tBodyGyroMag-arCoeff()3,)               float64
#  251  (tBodyGyroMag-arCoeff()4,)               float64
#  252  (tBodyGyroJerkMag-mean(),)               float64
#  253  (tBodyGyroJerkMag-std(),)                float64
#  254  (tBodyGyroJerkMag-mad(),)                float64
#  255  (tBodyGyroJerkMag-max(),)                float64
#  256  (tBodyGyroJerkMag-min(),)                float64
#  257  (tBodyGyroJerkMag-sma(),)                float64
#  258  (tBodyGyroJerkMag-energy(),)             float64
#  259  (tBodyGyroJerkMag-iqr(),)                float64
#  260  (tBodyGyroJerkMag-entropy(),)            float64
#  261  (tBodyGyroJerkMag-arCoeff()1,)           float64
#  262  (tBodyGyroJerkMag-arCoeff()2,)           float64
#  263  (tBodyGyroJerkMag-arCoeff()3,)           float64
#  264  (tBodyGyroJerkMag-arCoeff()4,)           float64
#  265  (fBodyAcc-mean()-X,)                     float64
#  266  (fBodyAcc-mean()-Y,)                     float64
#  267  (fBodyAcc-mean()-Z,)                     float64
#  268  (fBodyAcc-std()-X,)                      float64
#  269  (fBodyAcc-std()-Y,)                      float64
#  270  (fBodyAcc-std()-Z,)                      float64
#  271  (fBodyAcc-mad()-X,)                      float64
#  272  (fBodyAcc-mad()-Y,)                      float64
#  273  (fBodyAcc-mad()-Z,)                      float64
#  274  (fBodyAcc-max()-X,)                      float64
#  275  (fBodyAcc-max()-Y,)                      float64
#  276  (fBodyAcc-max()-Z,)                      float64
#  277  (fBodyAcc-min()-X,)                      float64
#  278  (fBodyAcc-min()-Y,)                      float64
#  279  (fBodyAcc-min()-Z,)                      float64
#  280  (fBodyAcc-sma(),)                        float64
#  281  (fBodyAcc-energy()-X,)                   float64
#  282  (fBodyAcc-energy()-Y,)                   float64
#  283  (fBodyAcc-energy()-Z,)                   float64
#  284  (fBodyAcc-iqr()-X,)                      float64
#  285  (fBodyAcc-iqr()-Y,)                      float64
#  286  (fBodyAcc-iqr()-Z,)                      float64
#  287  (fBodyAcc-entropy()-X,)                  float64
#  288  (fBodyAcc-entropy()-Y,)                  float64
#  289  (fBodyAcc-entropy()-Z,)                  float64
#  290  (fBodyAcc-maxInds-X,)                    float64
#  291  (fBodyAcc-maxInds-Y,)                    float64
#  292  (fBodyAcc-maxInds-Z,)                    float64
#  293  (fBodyAcc-meanFreq()-X,)                 float64
#  294  (fBodyAcc-meanFreq()-Y,)                 float64
#  295  (fBodyAcc-meanFreq()-Z,)                 float64
#  296  (fBodyAcc-skewness()-X,)                 float64
#  297  (fBodyAcc-kurtosis()-X,)                 float64
#  298  (fBodyAcc-skewness()-Y,)                 float64
#  299  (fBodyAcc-kurtosis()-Y,)                 float64
#  300  (fBodyAcc-skewness()-Z,)                 float64
#  301  (fBodyAcc-kurtosis()-Z,)                 float64
#  302  (fBodyAcc-bandsEnergy()-1,8,)            float64
#  303  (fBodyAcc-bandsEnergy()-9,16,)           float64
#  304  (fBodyAcc-bandsEnergy()-17,24,)          float64
#  305  (fBodyAcc-bandsEnergy()-25,32,)          float64
#  306  (fBodyAcc-bandsEnergy()-33,40,)          float64
#  307  (fBodyAcc-bandsEnergy()-41,48,)          float64
#  308  (fBodyAcc-bandsEnergy()-49,56,)          float64
#  309  (fBodyAcc-bandsEnergy()-57,64,)          float64
#  310  (fBodyAcc-bandsEnergy()-1,16,)           float64
#  311  (fBodyAcc-bandsEnergy()-17,32,)          float64
#  312  (fBodyAcc-bandsEnergy()-33,48,)          float64
#  313  (fBodyAcc-bandsEnergy()-49,64,)          float64
#  314  (fBodyAcc-bandsEnergy()-1,24,)           float64
#  315  (fBodyAcc-bandsEnergy()-25,48,)          float64
#  316  (fBodyAcc-bandsEnergy()-1,8,)            float64
#  317  (fBodyAcc-bandsEnergy()-9,16,)           float64
#  318  (fBodyAcc-bandsEnergy()-17,24,)          float64
#  319  (fBodyAcc-bandsEnergy()-25,32,)          float64
#  320  (fBodyAcc-bandsEnergy()-33,40,)          float64
#  321  (fBodyAcc-bandsEnergy()-41,48,)          float64
#  322  (fBodyAcc-bandsEnergy()-49,56,)          float64
#  323  (fBodyAcc-bandsEnergy()-57,64,)          float64
#  324  (fBodyAcc-bandsEnergy()-1,16,)           float64
#  325  (fBodyAcc-bandsEnergy()-17,32,)          float64
#  326  (fBodyAcc-bandsEnergy()-33,48,)          float64
#  327  (fBodyAcc-bandsEnergy()-49,64,)          float64
#  328  (fBodyAcc-bandsEnergy()-1,24,)           float64
#  329  (fBodyAcc-bandsEnergy()-25,48,)          float64
#  330  (fBodyAcc-bandsEnergy()-1,8,)            float64
#  331  (fBodyAcc-bandsEnergy()-9,16,)           float64
#  332  (fBodyAcc-bandsEnergy()-17,24,)          float64
#  333  (fBodyAcc-bandsEnergy()-25,32,)          float64
#  334  (fBodyAcc-bandsEnergy()-33,40,)          float64
#  335  (fBodyAcc-bandsEnergy()-41,48,)          float64
#  336  (fBodyAcc-bandsEnergy()-49,56,)          float64
#  337  (fBodyAcc-bandsEnergy()-57,64,)          float64
#  338  (fBodyAcc-bandsEnergy()-1,16,)           float64
#  339  (fBodyAcc-bandsEnergy()-17,32,)          float64
#  340  (fBodyAcc-bandsEnergy()-33,48,)          float64
#  341  (fBodyAcc-bandsEnergy()-49,64,)          float64
#  342  (fBodyAcc-bandsEnergy()-1,24,)           float64
#  343  (fBodyAcc-bandsEnergy()-25,48,)          float64
#  344  (fBodyAccJerk-mean()-X,)                 float64
#  345  (fBodyAccJerk-mean()-Y,)                 float64
#  346  (fBodyAccJerk-mean()-Z,)                 float64
#  347  (fBodyAccJerk-std()-X,)                  float64
#  348  (fBodyAccJerk-std()-Y,)                  float64
#  349  (fBodyAccJerk-std()-Z,)                  float64
#  350  (fBodyAccJerk-mad()-X,)                  float64
#  351  (fBodyAccJerk-mad()-Y,)                  float64
#  352  (fBodyAccJerk-mad()-Z,)                  float64
#  353  (fBodyAccJerk-max()-X,)                  float64
#  354  (fBodyAccJerk-max()-Y,)                  float64
#  355  (fBodyAccJerk-max()-Z,)                  float64
#  356  (fBodyAccJerk-min()-X,)                  float64
#  357  (fBodyAccJerk-min()-Y,)                  float64
#  358  (fBodyAccJerk-min()-Z,)                  float64
#  359  (fBodyAccJerk-sma(),)                    float64
#  360  (fBodyAccJerk-energy()-X,)               float64
#  361  (fBodyAccJerk-energy()-Y,)               float64
#  362  (fBodyAccJerk-energy()-Z,)               float64
#  363  (fBodyAccJerk-iqr()-X,)                  float64
#  364  (fBodyAccJerk-iqr()-Y,)                  float64
#  365  (fBodyAccJerk-iqr()-Z,)                  float64
#  366  (fBodyAccJerk-entropy()-X,)              float64
#  367  (fBodyAccJerk-entropy()-Y,)              float64
#  368  (fBodyAccJerk-entropy()-Z,)              float64
#  369  (fBodyAccJerk-maxInds-X,)                float64
#  370  (fBodyAccJerk-maxInds-Y,)                float64
#  371  (fBodyAccJerk-maxInds-Z,)                float64
#  372  (fBodyAccJerk-meanFreq()-X,)             float64
#  373  (fBodyAccJerk-meanFreq()-Y,)             float64
#  374  (fBodyAccJerk-meanFreq()-Z,)             float64
#  375  (fBodyAccJerk-skewness()-X,)             float64
#  376  (fBodyAccJerk-kurtosis()-X,)             float64
#  377  (fBodyAccJerk-skewness()-Y,)             float64
#  378  (fBodyAccJerk-kurtosis()-Y,)             float64
#  379  (fBodyAccJerk-skewness()-Z,)             float64
#  380  (fBodyAccJerk-kurtosis()-Z,)             float64
#  381  (fBodyAccJerk-bandsEnergy()-1,8,)        float64
#  382  (fBodyAccJerk-bandsEnergy()-9,16,)       float64
#  383  (fBodyAccJerk-bandsEnergy()-17,24,)      float64
#  384  (fBodyAccJerk-bandsEnergy()-25,32,)      float64
#  385  (fBodyAccJerk-bandsEnergy()-33,40,)      float64
#  386  (fBodyAccJerk-bandsEnergy()-41,48,)      float64
#  387  (fBodyAccJerk-bandsEnergy()-49,56,)      float64
#  388  (fBodyAccJerk-bandsEnergy()-57,64,)      float64
#  389  (fBodyAccJerk-bandsEnergy()-1,16,)       float64
#  390  (fBodyAccJerk-bandsEnergy()-17,32,)      float64
#  391  (fBodyAccJerk-bandsEnergy()-33,48,)      float64
#  392  (fBodyAccJerk-bandsEnergy()-49,64,)      float64
#  393  (fBodyAccJerk-bandsEnergy()-1,24,)       float64
#  394  (fBodyAccJerk-bandsEnergy()-25,48,)      float64
#  395  (fBodyAccJerk-bandsEnergy()-1,8,)        float64
#  396  (fBodyAccJerk-bandsEnergy()-9,16,)       float64
#  397  (fBodyAccJerk-bandsEnergy()-17,24,)      float64
#  398  (fBodyAccJerk-bandsEnergy()-25,32,)      float64
#  399  (fBodyAccJerk-bandsEnergy()-33,40,)      float64
#  400  (fBodyAccJerk-bandsEnergy()-41,48,)      float64
#  401  (fBodyAccJerk-bandsEnergy()-49,56,)      float64
#  402  (fBodyAccJerk-bandsEnergy()-57,64,)      float64
#  403  (fBodyAccJerk-bandsEnergy()-1,16,)       float64
#  404  (fBodyAccJerk-bandsEnergy()-17,32,)      float64
#  405  (fBodyAccJerk-bandsEnergy()-33,48,)      float64
#  406  (fBodyAccJerk-bandsEnergy()-49,64,)      float64
#  407  (fBodyAccJerk-bandsEnergy()-1,24,)       float64
#  408  (fBodyAccJerk-bandsEnergy()-25,48,)      float64
#  409  (fBodyAccJerk-bandsEnergy()-1,8,)        float64
#  410  (fBodyAccJerk-bandsEnergy()-9,16,)       float64
#  411  (fBodyAccJerk-bandsEnergy()-17,24,)      float64
#  412  (fBodyAccJerk-bandsEnergy()-25,32,)      float64
#  413  (fBodyAccJerk-bandsEnergy()-33,40,)      float64
#  414  (fBodyAccJerk-bandsEnergy()-41,48,)      float64
#  415  (fBodyAccJerk-bandsEnergy()-49,56,)      float64
#  416  (fBodyAccJerk-bandsEnergy()-57,64,)      float64
#  417  (fBodyAccJerk-bandsEnergy()-1,16,)       float64
#  418  (fBodyAccJerk-bandsEnergy()-17,32,)      float64
#  419  (fBodyAccJerk-bandsEnergy()-33,48,)      float64
#  420  (fBodyAccJerk-bandsEnergy()-49,64,)      float64
#  421  (fBodyAccJerk-bandsEnergy()-1,24,)       float64
#  422  (fBodyAccJerk-bandsEnergy()-25,48,)      float64
#  423  (fBodyGyro-mean()-X,)                    float64
#  424  (fBodyGyro-mean()-Y,)                    float64
#  425  (fBodyGyro-mean()-Z,)                    float64
#  426  (fBodyGyro-std()-X,)                     float64
#  427  (fBodyGyro-std()-Y,)                     float64
#  428  (fBodyGyro-std()-Z,)                     float64
#  429  (fBodyGyro-mad()-X,)                     float64
#  430  (fBodyGyro-mad()-Y,)                     float64
#  431  (fBodyGyro-mad()-Z,)                     float64
#  432  (fBodyGyro-max()-X,)                     float64
#  433  (fBodyGyro-max()-Y,)                     float64
#  434  (fBodyGyro-max()-Z,)                     float64
#  435  (fBodyGyro-min()-X,)                     float64
#  436  (fBodyGyro-min()-Y,)                     float64
#  437  (fBodyGyro-min()-Z,)                     float64
#  438  (fBodyGyro-sma(),)                       float64
#  439  (fBodyGyro-energy()-X,)                  float64
#  440  (fBodyGyro-energy()-Y,)                  float64
#  441  (fBodyGyro-energy()-Z,)                  float64
#  442  (fBodyGyro-iqr()-X,)                     float64
#  443  (fBodyGyro-iqr()-Y,)                     float64
#  444  (fBodyGyro-iqr()-Z,)                     float64
#  445  (fBodyGyro-entropy()-X,)                 float64
#  446  (fBodyGyro-entropy()-Y,)                 float64
#  447  (fBodyGyro-entropy()-Z,)                 float64
#  448  (fBodyGyro-maxInds-X,)                   float64
#  449  (fBodyGyro-maxInds-Y,)                   float64
#  450  (fBodyGyro-maxInds-Z,)                   float64
#  451  (fBodyGyro-meanFreq()-X,)                float64
#  452  (fBodyGyro-meanFreq()-Y,)                float64
#  453  (fBodyGyro-meanFreq()-Z,)                float64
#  454  (fBodyGyro-skewness()-X,)                float64
#  455  (fBodyGyro-kurtosis()-X,)                float64
#  456  (fBodyGyro-skewness()-Y,)                float64
#  457  (fBodyGyro-kurtosis()-Y,)                float64
#  458  (fBodyGyro-skewness()-Z,)                float64
#  459  (fBodyGyro-kurtosis()-Z,)                float64
#  460  (fBodyGyro-bandsEnergy()-1,8,)           float64
#  461  (fBodyGyro-bandsEnergy()-9,16,)          float64
#  462  (fBodyGyro-bandsEnergy()-17,24,)         float64
#  463  (fBodyGyro-bandsEnergy()-25,32,)         float64
#  464  (fBodyGyro-bandsEnergy()-33,40,)         float64
#  465  (fBodyGyro-bandsEnergy()-41,48,)         float64
#  466  (fBodyGyro-bandsEnergy()-49,56,)         float64
#  467  (fBodyGyro-bandsEnergy()-57,64,)         float64
#  468  (fBodyGyro-bandsEnergy()-1,16,)          float64
#  469  (fBodyGyro-bandsEnergy()-17,32,)         float64
#  470  (fBodyGyro-bandsEnergy()-33,48,)         float64
#  471  (fBodyGyro-bandsEnergy()-49,64,)         float64
#  472  (fBodyGyro-bandsEnergy()-1,24,)          float64
#  473  (fBodyGyro-bandsEnergy()-25,48,)         float64
#  474  (fBodyGyro-bandsEnergy()-1,8,)           float64
#  475  (fBodyGyro-bandsEnergy()-9,16,)          float64
#  476  (fBodyGyro-bandsEnergy()-17,24,)         float64
#  477  (fBodyGyro-bandsEnergy()-25,32,)         float64
#  478  (fBodyGyro-bandsEnergy()-33,40,)         float64
#  479  (fBodyGyro-bandsEnergy()-41,48,)         float64
#  480  (fBodyGyro-bandsEnergy()-49,56,)         float64
#  481  (fBodyGyro-bandsEnergy()-57,64,)         float64
#  482  (fBodyGyro-bandsEnergy()-1,16,)          float64
#  483  (fBodyGyro-bandsEnergy()-17,32,)         float64
#  484  (fBodyGyro-bandsEnergy()-33,48,)         float64
#  485  (fBodyGyro-bandsEnergy()-49,64,)         float64
#  486  (fBodyGyro-bandsEnergy()-1,24,)          float64
#  487  (fBodyGyro-bandsEnergy()-25,48,)         float64
#  488  (fBodyGyro-bandsEnergy()-1,8,)           float64
#  489  (fBodyGyro-bandsEnergy()-9,16,)          float64
#  490  (fBodyGyro-bandsEnergy()-17,24,)         float64
#  491  (fBodyGyro-bandsEnergy()-25,32,)         float64
#  492  (fBodyGyro-bandsEnergy()-33,40,)         float64
#  493  (fBodyGyro-bandsEnergy()-41,48,)         float64
#  494  (fBodyGyro-bandsEnergy()-49,56,)         float64
#  495  (fBodyGyro-bandsEnergy()-57,64,)         float64
#  496  (fBodyGyro-bandsEnergy()-1,16,)          float64
#  497  (fBodyGyro-bandsEnergy()-17,32,)         float64
#  498  (fBodyGyro-bandsEnergy()-33,48,)         float64
#  499  (fBodyGyro-bandsEnergy()-49,64,)         float64
#  500  (fBodyGyro-bandsEnergy()-1,24,)          float64
#  501  (fBodyGyro-bandsEnergy()-25,48,)         float64
#  502  (fBodyAccMag-mean(),)                    float64
#  503  (fBodyAccMag-std(),)                     float64
#  504  (fBodyAccMag-mad(),)                     float64
#  505  (fBodyAccMag-max(),)                     float64
#  506  (fBodyAccMag-min(),)                     float64
#  507  (fBodyAccMag-sma(),)                     float64
#  508  (fBodyAccMag-energy(),)                  float64
#  509  (fBodyAccMag-iqr(),)                     float64
#  510  (fBodyAccMag-entropy(),)                 float64
#  511  (fBodyAccMag-maxInds,)                   float64
#  512  (fBodyAccMag-meanFreq(),)                float64
#  513  (fBodyAccMag-skewness(),)                float64
#  514  (fBodyAccMag-kurtosis(),)                float64
#  515  (fBodyBodyAccJerkMag-mean(),)            float64
#  516  (fBodyBodyAccJerkMag-std(),)             float64
#  517  (fBodyBodyAccJerkMag-mad(),)             float64
#  518  (fBodyBodyAccJerkMag-max(),)             float64
#  519  (fBodyBodyAccJerkMag-min(),)             float64
#  520  (fBodyBodyAccJerkMag-sma(),)             float64
#  521  (fBodyBodyAccJerkMag-energy(),)          float64
#  522  (fBodyBodyAccJerkMag-iqr(),)             float64
#  523  (fBodyBodyAccJerkMag-entropy(),)         float64
#  524  (fBodyBodyAccJerkMag-maxInds,)           float64
#  525  (fBodyBodyAccJerkMag-meanFreq(),)        float64
#  526  (fBodyBodyAccJerkMag-skewness(),)        float64
#  527  (fBodyBodyAccJerkMag-kurtosis(),)        float64
#  528  (fBodyBodyGyroMag-mean(),)               float64
#  529  (fBodyBodyGyroMag-std(),)                float64
#  530  (fBodyBodyGyroMag-mad(),)                float64
#  531  (fBodyBodyGyroMag-max(),)                float64
#  532  (fBodyBodyGyroMag-min(),)                float64
#  533  (fBodyBodyGyroMag-sma(),)                float64
#  534  (fBodyBodyGyroMag-energy(),)             float64
#  535  (fBodyBodyGyroMag-iqr(),)                float64
#  536  (fBodyBodyGyroMag-entropy(),)            float64
#  537  (fBodyBodyGyroMag-maxInds,)              float64
#  538  (fBodyBodyGyroMag-meanFreq(),)           float64
#  539  (fBodyBodyGyroMag-skewness(),)           float64
#  540  (fBodyBodyGyroMag-kurtosis(),)           float64
#  541  (fBodyBodyGyroJerkMag-mean(),)           float64
#  542  (fBodyBodyGyroJerkMag-std(),)            float64
#  543  (fBodyBodyGyroJerkMag-mad(),)            float64
#  544  (fBodyBodyGyroJerkMag-max(),)            float64
#  545  (fBodyBodyGyroJerkMag-min(),)            float64
#  546  (fBodyBodyGyroJerkMag-sma(),)            float64
#  547  (fBodyBodyGyroJerkMag-energy(),)         float64
#  548  (fBodyBodyGyroJerkMag-iqr(),)            float64
#  549  (fBodyBodyGyroJerkMag-entropy(),)        float64
#  550  (fBodyBodyGyroJerkMag-maxInds,)          float64
#  551  (fBodyBodyGyroJerkMag-meanFreq(),)       float64
#  552  (fBodyBodyGyroJerkMag-skewness(),)       float64
#  553  (fBodyBodyGyroJerkMag-kurtosis(),)       float64
#  554  (angle(tBodyAccMean,gravity),)           float64
#  555  (angle(tBodyAccJerkMean),gravityMean),)  float64
#  556  (angle(tBodyGyroMean,gravityMean),)      float64
#  557  (angle(tBodyGyroJerkMean,gravityMean),)  float64
#  558  (angle(X,gravityMean),)                  float64
#  559  (angle(Y,gravityMean),)                  float64
#  560  (angle(Z,gravityMean),)                  float64
#  561  (subjectid,)                             int64
#  562  (activity,)                              int64
#  563  (activityname,)                          object
# dtypes: float64(561), int64(2), object(1)
# memory usage: 31.6+ MB

# %%
traindf.describe(include='all')
# Out:
#        tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# count        7352.000000       7352.000000       7352.000000      7352.000000
# unique               NaN               NaN               NaN              NaN
# top                  NaN               NaN               NaN              NaN
# freq                 NaN               NaN               NaN              NaN
# mean            0.274488         -0.017695         -0.109141        -0.605438
# std             0.070261          0.040811          0.056635         0.448734
# min            -1.000000         -1.000000         -1.000000        -1.000000
# 25%             0.262975         -0.024863         -0.120993        -0.992754
# 50%             0.277193         -0.017219         -0.108676        -0.946196
# 75%             0.288461         -0.010783         -0.097794        -0.242813
# max             1.000000          1.000000          1.000000         1.000000
#
#        tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# count       7352.000000      7352.000000      7352.000000      7352.000000
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean          -0.510938        -0.604754        -0.630512        -0.526907
# std            0.502645         0.418687         0.424073         0.485942
# min           -0.999873        -1.000000        -1.000000        -1.000000
# 25%           -0.978129        -0.980233        -0.993591        -0.978162
# 50%           -0.851897        -0.859365        -0.950709        -0.857328
# 75%           -0.034231        -0.262415        -0.292680        -0.066701
# max            0.916238         1.000000         1.000000         0.967664
#
#        tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# count       7352.000000      7352.000000  ...                 7352.000000
# unique              NaN              NaN  ...                         NaN
# top                 NaN              NaN  ...                         NaN
# freq                NaN              NaN  ...                         NaN
# mean          -0.606150        -0.468604  ...                    0.008684
# std            0.414122         0.544547  ...                    0.336787
# min           -1.000000        -1.000000  ...                   -0.976580
# 25%           -0.980251        -0.936219  ...                   -0.121527
# 50%           -0.857143        -0.881637  ...                    0.009509
# 75%           -0.265671        -0.017129  ...                    0.150865
# max            1.000000         1.000000  ...                    1.000000
#
#        angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# count                           7352.000000                      7352.000000
# unique                                  NaN                              NaN
# top                                     NaN                              NaN
# freq                                    NaN                              NaN
# mean                               0.002186                         0.008726
# std                                0.448306                         0.608303
# min                               -1.000000                        -1.000000
# 25%                               -0.289549                        -0.482273
# 50%                                0.008943                         0.008735
# 75%                                0.292861                         0.506187
# max                                1.000000                         0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# count                           7352.000000          7352.000000
# unique                                  NaN                  NaN
# top                                     NaN                  NaN
# freq                                    NaN                  NaN
# mean                              -0.005981            -0.489547
# std                                0.477975             0.511807
# min                               -1.000000            -1.000000
# 25%                               -0.376341            -0.812065
# 50%                               -0.000368            -0.709417
# 75%                                0.359368            -0.509079
# max                                0.996078             1.000000
#
#        angle(Y,gravityMean) angle(Z,gravityMean)    subjectid     activity  \
# count           7352.000000          7352.000000  7352.000000  7352.000000
# unique                  NaN                  NaN          NaN          NaN
# top                     NaN                  NaN          NaN          NaN
# freq                    NaN                  NaN          NaN          NaN
# mean               0.058593            -0.056515    17.413085     3.643362
# std                0.297480             0.279122     8.975143     1.744802
# min               -1.000000            -1.000000     1.000000     1.000000
# 25%               -0.017885            -0.143414     8.000000     2.000000
# 50%                0.182071             0.003181    19.000000     4.000000
# 75%                0.248353             0.107659    26.000000     5.000000
# max                0.478157             1.000000    30.000000     6.000000
#
#        activityname
# count          7352
# unique            6
# top          LAYING
# freq           1407
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN
#
# [11 rows x 564 columns]

# %%
#Exploring null values
print(traindf.isna().sum().sum())
# Out:
# 0

# %%
#NOW WORKING ON TEST DATA--> Creating Data Frame of Test data

# %%
testdf = pd.read_csv(r'C:\Users\adity\har\test\X_test.txt', delim_whitespace=True, header=None)
testdf.columns = [features]
#adding new column of subject id , to which subject[1-30] data is associated with. 
testdf['subjectid'] = pd.read_csv(r'C:\Users\adity\har\test\subject_test.txt', header=None)
#adding new column of activity from reding y_train file 
testdf['activity'] = pd.read_csv(r'C:\Users\adity\har\test\y_test.txt', header=None)

#Converting labels to designated numerical labels (kind of label encoding)
activity = np.array(testdf.loc[:,"activity"])
activityname = []

for i in range(len(activity)):
    if activity[i] == 1:
        activityname.append('WALKING')
    elif activity[i] == 2:
        activityname.append('WALKING_UPSTAIRS')
    elif activity[i] == 3:
        activityname.append('WALKING_DOWNSTAIRS')
    elif activity[i] == 4:
        activityname.append('SITTING')
    elif activity[i] == 5:
        activityname.append('STANDING')
    elif activity[i] == 6:
        activityname.append('LAYING')

testdf['activityname'] = np.array(activityname)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_17060\489421259.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   testdf = pd.read_csv(r'C:\Users\adity\har\test\X_test.txt', delim_whitespace=True, header=None)

# %%
testdf.head()
# Out:
#   tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0          0.257178         -0.023285         -0.014654        -0.938404
# 1          0.286027         -0.013163         -0.119083        -0.975415
# 2          0.275485         -0.026050         -0.118152        -0.993819
# 3          0.270298         -0.032614         -0.117520        -0.994743
# 4          0.274833         -0.027848         -0.129527        -0.993852
#
#   tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0        -0.920091        -0.667683        -0.952501        -0.925249
# 1        -0.967458        -0.944958        -0.986799        -0.968401
# 2        -0.969926        -0.962748        -0.994403        -0.970735
# 3        -0.973268        -0.967091        -0.995274        -0.974471
# 4        -0.967445        -0.978295        -0.994111        -0.965953
#
#   tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0        -0.674302        -0.894088  ...                    0.006462
# 1        -0.945823        -0.894088  ...                   -0.083495
# 2        -0.963483        -0.939260  ...                   -0.034956
# 3        -0.968897        -0.938610  ...                   -0.017067
# 4        -0.977346        -0.938610  ...                   -0.002223
#
#   angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                             0.162920                        -0.825886
# 1                             0.017500                        -0.434375
# 2                             0.202302                         0.064103
# 3                             0.154438                         0.340134
# 4                            -0.040046                         0.736715
#
#   angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                             0.271151            -0.720009
# 1                             0.920593            -0.698091
# 2                             0.145068            -0.702771
# 3                             0.296407            -0.698954
# 4                            -0.118545            -0.692245
#
#   angle(Y,gravityMean) angle(Z,gravityMean) subjectid activity activityname
# 0             0.276801            -0.057978         2        5     STANDING
# 1             0.281343            -0.083898         2        5     STANDING
# 2             0.280083            -0.079346         2        5     STANDING
# 3             0.284114            -0.077108         2        5     STANDING
# 4             0.290722            -0.073857         2        5     STANDING
#
# [5 rows x 564 columns]

# %%
testdf.shape
# Out:
# (2947, 564)

# %%
testdf.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Data columns (total 564 columns):
#  #    Column                                   Dtype
# ---   ------                                   -----
#  0    (tBodyAcc-mean()-X,)                     float64
#  1    (tBodyAcc-mean()-Y,)                     float64
#  2    (tBodyAcc-mean()-Z,)                     float64
#  3    (tBodyAcc-std()-X,)                      float64
#  4    (tBodyAcc-std()-Y,)                      float64
#  5    (tBodyAcc-std()-Z,)                      float64
#  6    (tBodyAcc-mad()-X,)                      float64
#  7    (tBodyAcc-mad()-Y,)                      float64
#  8    (tBodyAcc-mad()-Z,)                      float64
#  9    (tBodyAcc-max()-X,)                      float64
#  10   (tBodyAcc-max()-Y,)                      float64
#  11   (tBodyAcc-max()-Z,)                      float64
#  12   (tBodyAcc-min()-X,)                      float64
#  13   (tBodyAcc-min()-Y,)                      float64
#  14   (tBodyAcc-min()-Z,)                      float64
#  15   (tBodyAcc-sma(),)                        float64
#  16   (tBodyAcc-energy()-X,)                   float64
#  17   (tBodyAcc-energy()-Y,)                   float64
#  18   (tBodyAcc-energy()-Z,)                   float64
#  19   (tBodyAcc-iqr()-X,)                      float64
#  20   (tBodyAcc-iqr()-Y,)                      float64
#  21   (tBodyAcc-iqr()-Z,)                      float64
#  22   (tBodyAcc-entropy()-X,)                  float64
#  23   (tBodyAcc-entropy()-Y,)                  float64
#  24   (tBodyAcc-entropy()-Z,)                  float64
#  25   (tBodyAcc-arCoeff()-X,1,)                float64
#  26   (tBodyAcc-arCoeff()-X,2,)                float64
#  27   (tBodyAcc-arCoeff()-X,3,)                float64
#  28   (tBodyAcc-arCoeff()-X,4,)                float64
#  29   (tBodyAcc-arCoeff()-Y,1,)                float64
#  30   (tBodyAcc-arCoeff()-Y,2,)                float64
#  31   (tBodyAcc-arCoeff()-Y,3,)                float64
#  32   (tBodyAcc-arCoeff()-Y,4,)                float64
#  33   (tBodyAcc-arCoeff()-Z,1,)                float64
#  34   (tBodyAcc-arCoeff()-Z,2,)                float64
#  35   (tBodyAcc-arCoeff()-Z,3,)                float64
#  36   (tBodyAcc-arCoeff()-Z,4,)                float64
#  37   (tBodyAcc-correlation()-X,Y,)            float64
#  38   (tBodyAcc-correlation()-X,Z,)            float64
#  39   (tBodyAcc-correlation()-Y,Z,)            float64
#  40   (tGravityAcc-mean()-X,)                  float64
#  41   (tGravityAcc-mean()-Y,)                  float64
#  42   (tGravityAcc-mean()-Z,)                  float64
#  43   (tGravityAcc-std()-X,)                   float64
#  44   (tGravityAcc-std()-Y,)                   float64
#  45   (tGravityAcc-std()-Z,)                   float64
#  46   (tGravityAcc-mad()-X,)                   float64
#  47   (tGravityAcc-mad()-Y,)                   float64
#  48   (tGravityAcc-mad()-Z,)                   float64
#  49   (tGravityAcc-max()-X,)                   float64
#  50   (tGravityAcc-max()-Y,)                   float64
#  51   (tGravityAcc-max()-Z,)                   float64
#  52   (tGravityAcc-min()-X,)                   float64
#  53   (tGravityAcc-min()-Y,)                   float64
#  54   (tGravityAcc-min()-Z,)                   float64
#  55   (tGravityAcc-sma(),)                     float64
#  56   (tGravityAcc-energy()-X,)                float64
#  57   (tGravityAcc-energy()-Y,)                float64
#  58   (tGravityAcc-energy()-Z,)                float64
#  59   (tGravityAcc-iqr()-X,)                   float64
#  60   (tGravityAcc-iqr()-Y,)                   float64
#  61   (tGravityAcc-iqr()-Z,)                   float64
#  62   (tGravityAcc-entropy()-X,)               float64
#  63   (tGravityAcc-entropy()-Y,)               float64
#  64   (tGravityAcc-entropy()-Z,)               float64
#  65   (tGravityAcc-arCoeff()-X,1,)             float64
#  66   (tGravityAcc-arCoeff()-X,2,)             float64
#  67   (tGravityAcc-arCoeff()-X,3,)             float64
#  68   (tGravityAcc-arCoeff()-X,4,)             float64
#  69   (tGravityAcc-arCoeff()-Y,1,)             float64
#  70   (tGravityAcc-arCoeff()-Y,2,)             float64
#  71   (tGravityAcc-arCoeff()-Y,3,)             float64
#  72   (tGravityAcc-arCoeff()-Y,4,)             float64
#  73   (tGravityAcc-arCoeff()-Z,1,)             float64
#  74   (tGravityAcc-arCoeff()-Z,2,)             float64
#  75   (tGravityAcc-arCoeff()-Z,3,)             float64
#  76   (tGravityAcc-arCoeff()-Z,4,)             float64
#  77   (tGravityAcc-correlation()-X,Y,)         float64
#  78   (tGravityAcc-correlation()-X,Z,)         float64
#  79   (tGravityAcc-correlation()-Y,Z,)         float64
#  80   (tBodyAccJerk-mean()-X,)                 float64
#  81   (tBodyAccJerk-mean()-Y,)                 float64
#  82   (tBodyAccJerk-mean()-Z,)                 float64
#  83   (tBodyAccJerk-std()-X,)                  float64
#  84   (tBodyAccJerk-std()-Y,)                  float64
#  85   (tBodyAccJerk-std()-Z,)                  float64
#  86   (tBodyAccJerk-mad()-X,)                  float64
#  87   (tBodyAccJerk-mad()-Y,)                  float64
#  88   (tBodyAccJerk-mad()-Z,)                  float64
#  89   (tBodyAccJerk-max()-X,)                  float64
#  90   (tBodyAccJerk-max()-Y,)                  float64
#  91   (tBodyAccJerk-max()-Z,)                  float64
#  92   (tBodyAccJerk-min()-X,)                  float64
#  93   (tBodyAccJerk-min()-Y,)                  float64
#  94   (tBodyAccJerk-min()-Z,)                  float64
#  95   (tBodyAccJerk-sma(),)                    float64
#  96   (tBodyAccJerk-energy()-X,)               float64
#  97   (tBodyAccJerk-energy()-Y,)               float64
#  98   (tBodyAccJerk-energy()-Z,)               float64
#  99   (tBodyAccJerk-iqr()-X,)                  float64
#  100  (tBodyAccJerk-iqr()-Y,)                  float64
#  101  (tBodyAccJerk-iqr()-Z,)                  float64
#  102  (tBodyAccJerk-entropy()-X,)              float64
#  103  (tBodyAccJerk-entropy()-Y,)              float64
#  104  (tBodyAccJerk-entropy()-Z,)              float64
#  105  (tBodyAccJerk-arCoeff()-X,1,)            float64
#  106  (tBodyAccJerk-arCoeff()-X,2,)            float64
#  107  (tBodyAccJerk-arCoeff()-X,3,)            float64
#  108  (tBodyAccJerk-arCoeff()-X,4,)            float64
#  109  (tBodyAccJerk-arCoeff()-Y,1,)            float64
#  110  (tBodyAccJerk-arCoeff()-Y,2,)            float64
#  111  (tBodyAccJerk-arCoeff()-Y,3,)            float64
#  112  (tBodyAccJerk-arCoeff()-Y,4,)            float64
#  113  (tBodyAccJerk-arCoeff()-Z,1,)            float64
#  114  (tBodyAccJerk-arCoeff()-Z,2,)            float64
#  115  (tBodyAccJerk-arCoeff()-Z,3,)            float64
#  116  (tBodyAccJerk-arCoeff()-Z,4,)            float64
#  117  (tBodyAccJerk-correlation()-X,Y,)        float64
#  118  (tBodyAccJerk-correlation()-X,Z,)        float64
#  119  (tBodyAccJerk-correlation()-Y,Z,)        float64
#  120  (tBodyGyro-mean()-X,)                    float64
#  121  (tBodyGyro-mean()-Y,)                    float64
#  122  (tBodyGyro-mean()-Z,)                    float64
#  123  (tBodyGyro-std()-X,)                     float64
#  124  (tBodyGyro-std()-Y,)                     float64
#  125  (tBodyGyro-std()-Z,)                     float64
#  126  (tBodyGyro-mad()-X,)                     float64
#  127  (tBodyGyro-mad()-Y,)                     float64
#  128  (tBodyGyro-mad()-Z,)                     float64
#  129  (tBodyGyro-max()-X,)                     float64
#  130  (tBodyGyro-max()-Y,)                     float64
#  131  (tBodyGyro-max()-Z,)                     float64
#  132  (tBodyGyro-min()-X,)                     float64
#  133  (tBodyGyro-min()-Y,)                     float64
#  134  (tBodyGyro-min()-Z,)                     float64
#  135  (tBodyGyro-sma(),)                       float64
#  136  (tBodyGyro-energy()-X,)                  float64
#  137  (tBodyGyro-energy()-Y,)                  float64
#  138  (tBodyGyro-energy()-Z,)                  float64
#  139  (tBodyGyro-iqr()-X,)                     float64
#  140  (tBodyGyro-iqr()-Y,)                     float64
#  141  (tBodyGyro-iqr()-Z,)                     float64
#  142  (tBodyGyro-entropy()-X,)                 float64
#  143  (tBodyGyro-entropy()-Y,)                 float64
#  144  (tBodyGyro-entropy()-Z,)                 float64
#  145  (tBodyGyro-arCoeff()-X,1,)               float64
#  146  (tBodyGyro-arCoeff()-X,2,)               float64
#  147  (tBodyGyro-arCoeff()-X,3,)               float64
#  148  (tBodyGyro-arCoeff()-X,4,)               float64
#  149  (tBodyGyro-arCoeff()-Y,1,)               float64
#  150  (tBodyGyro-arCoeff()-Y,2,)               float64
#  151  (tBodyGyro-arCoeff()-Y,3,)               float64
#  152  (tBodyGyro-arCoeff()-Y,4,)               float64
#  153  (tBodyGyro-arCoeff()-Z,1,)               float64
#  154  (tBodyGyro-arCoeff()-Z,2,)               float64
#  155  (tBodyGyro-arCoeff()-Z,3,)               float64
#  156  (tBodyGyro-arCoeff()-Z,4,)               float64
#  157  (tBodyGyro-correlation()-X,Y,)           float64
#  158  (tBodyGyro-correlation()-X,Z,)           float64
#  159  (tBodyGyro-correlation()-Y,Z,)           float64
#  160  (tBodyGyroJerk-mean()-X,)                float64
#  161  (tBodyGyroJerk-mean()-Y,)                float64
#  162  (tBodyGyroJerk-mean()-Z,)                float64
#  163  (tBodyGyroJerk-std()-X,)                 float64
#  164  (tBodyGyroJerk-std()-Y,)                 float64
#  165  (tBodyGyroJerk-std()-Z,)                 float64
#  166  (tBodyGyroJerk-mad()-X,)                 float64
#  167  (tBodyGyroJerk-mad()-Y,)                 float64
#  168  (tBodyGyroJerk-mad()-Z,)                 float64
#  169  (tBodyGyroJerk-max()-X,)                 float64
#  170  (tBodyGyroJerk-max()-Y,)                 float64
#  171  (tBodyGyroJerk-max()-Z,)                 float64
#  172  (tBodyGyroJerk-min()-X,)                 float64
#  173  (tBodyGyroJerk-min()-Y,)                 float64
#  174  (tBodyGyroJerk-min()-Z,)                 float64
#  175  (tBodyGyroJerk-sma(),)                   float64
#  176  (tBodyGyroJerk-energy()-X,)              float64
#  177  (tBodyGyroJerk-energy()-Y,)              float64
#  178  (tBodyGyroJerk-energy()-Z,)              float64
#  179  (tBodyGyroJerk-iqr()-X,)                 float64
#  180  (tBodyGyroJerk-iqr()-Y,)                 float64
#  181  (tBodyGyroJerk-iqr()-Z,)                 float64
#  182  (tBodyGyroJerk-entropy()-X,)             float64
#  183  (tBodyGyroJerk-entropy()-Y,)             float64
#  184  (tBodyGyroJerk-entropy()-Z,)             float64
#  185  (tBodyGyroJerk-arCoeff()-X,1,)           float64
#  186  (tBodyGyroJerk-arCoeff()-X,2,)           float64
#  187  (tBodyGyroJerk-arCoeff()-X,3,)           float64
#  188  (tBodyGyroJerk-arCoeff()-X,4,)           float64
#  189  (tBodyGyroJerk-arCoeff()-Y,1,)           float64
#  190  (tBodyGyroJerk-arCoeff()-Y,2,)           float64
#  191  (tBodyGyroJerk-arCoeff()-Y,3,)           float64
#  192  (tBodyGyroJerk-arCoeff()-Y,4,)           float64
#  193  (tBodyGyroJerk-arCoeff()-Z,1,)           float64
#  194  (tBodyGyroJerk-arCoeff()-Z,2,)           float64
#  195  (tBodyGyroJerk-arCoeff()-Z,3,)           float64
#  196  (tBodyGyroJerk-arCoeff()-Z,4,)           float64
#  197  (tBodyGyroJerk-correlation()-X,Y,)       float64
#  198  (tBodyGyroJerk-correlation()-X,Z,)       float64
#  199  (tBodyGyroJerk-correlation()-Y,Z,)       float64
#  200  (tBodyAccMag-mean(),)                    float64
#  201  (tBodyAccMag-std(),)                     float64
#  202  (tBodyAccMag-mad(),)                     float64
#  203  (tBodyAccMag-max(),)                     float64
#  204  (tBodyAccMag-min(),)                     float64
#  205  (tBodyAccMag-sma(),)                     float64
#  206  (tBodyAccMag-energy(),)                  float64
#  207  (tBodyAccMag-iqr(),)                     float64
#  208  (tBodyAccMag-entropy(),)                 float64
#  209  (tBodyAccMag-arCoeff()1,)                float64
#  210  (tBodyAccMag-arCoeff()2,)                float64
#  211  (tBodyAccMag-arCoeff()3,)                float64
#  212  (tBodyAccMag-arCoeff()4,)                float64
#  213  (tGravityAccMag-mean(),)                 float64
#  214  (tGravityAccMag-std(),)                  float64
#  215  (tGravityAccMag-mad(),)                  float64
#  216  (tGravityAccMag-max(),)                  float64
#  217  (tGravityAccMag-min(),)                  float64
#  218  (tGravityAccMag-sma(),)                  float64
#  219  (tGravityAccMag-energy(),)               float64
#  220  (tGravityAccMag-iqr(),)                  float64
#  221  (tGravityAccMag-entropy(),)              float64
#  222  (tGravityAccMag-arCoeff()1,)             float64
#  223  (tGravityAccMag-arCoeff()2,)             float64
#  224  (tGravityAccMag-arCoeff()3,)             float64
#  225  (tGravityAccMag-arCoeff()4,)             float64
#  226  (tBodyAccJerkMag-mean(),)                float64
#  227  (tBodyAccJerkMag-std(),)                 float64
#  228  (tBodyAccJerkMag-mad(),)                 float64
#  229  (tBodyAccJerkMag-max(),)                 float64
#  230  (tBodyAccJerkMag-min(),)                 float64
#  231  (tBodyAccJerkMag-sma(),)                 float64
#  232  (tBodyAccJerkMag-energy(),)              float64
#  233  (tBodyAccJerkMag-iqr(),)                 float64
#  234  (tBodyAccJerkMag-entropy(),)             float64
#  235  (tBodyAccJerkMag-arCoeff()1,)            float64
#  236  (tBodyAccJerkMag-arCoeff()2,)            float64
#  237  (tBodyAccJerkMag-arCoeff()3,)            float64
#  238  (tBodyAccJerkMag-arCoeff()4,)            float64
#  239  (tBodyGyroMag-mean(),)                   float64
#  240  (tBodyGyroMag-std(),)                    float64
#  241  (tBodyGyroMag-mad(),)                    float64
#  242  (tBodyGyroMag-max(),)                    float64
#  243  (tBodyGyroMag-min(),)                    float64
#  244  (tBodyGyroMag-sma(),)                    float64
#  245  (tBodyGyroMag-energy(),)                 float64
#  246  (tBodyGyroMag-iqr(),)                    float64
#  247  (tBodyGyroMag-entropy(),)                float64
#  248  (tBodyGyroMag-arCoeff()1,)               float64
#  249  (tBodyGyroMag-arCoeff()2,)               float64
#  250  (tBodyGyroMag-arCoeff()3,)               float64
#  251  (tBodyGyroMag-arCoeff()4,)               float64
#  252  (tBodyGyroJerkMag-mean(),)               float64
#  253  (tBodyGyroJerkMag-std(),)                float64
#  254  (tBodyGyroJerkMag-mad(),)                float64
#  255  (tBodyGyroJerkMag-max(),)                float64
#  256  (tBodyGyroJerkMag-min(),)                float64
#  257  (tBodyGyroJerkMag-sma(),)                float64
#  258  (tBodyGyroJerkMag-energy(),)             float64
#  259  (tBodyGyroJerkMag-iqr(),)                float64
#  260  (tBodyGyroJerkMag-entropy(),)            float64
#  261  (tBodyGyroJerkMag-arCoeff()1,)           float64
#  262  (tBodyGyroJerkMag-arCoeff()2,)           float64
#  263  (tBodyGyroJerkMag-arCoeff()3,)           float64
#  264  (tBodyGyroJerkMag-arCoeff()4,)           float64
#  265  (fBodyAcc-mean()-X,)                     float64
#  266  (fBodyAcc-mean()-Y,)                     float64
#  267  (fBodyAcc-mean()-Z,)                     float64
#  268  (fBodyAcc-std()-X,)                      float64
#  269  (fBodyAcc-std()-Y,)                      float64
#  270  (fBodyAcc-std()-Z,)                      float64
#  271  (fBodyAcc-mad()-X,)                      float64
#  272  (fBodyAcc-mad()-Y,)                      float64
#  273  (fBodyAcc-mad()-Z,)                      float64
#  274  (fBodyAcc-max()-X,)                      float64
#  275  (fBodyAcc-max()-Y,)                      float64
#  276  (fBodyAcc-max()-Z,)                      float64
#  277  (fBodyAcc-min()-X,)                      float64
#  278  (fBodyAcc-min()-Y,)                      float64
#  279  (fBodyAcc-min()-Z,)                      float64
#  280  (fBodyAcc-sma(),)                        float64
#  281  (fBodyAcc-energy()-X,)                   float64
#  282  (fBodyAcc-energy()-Y,)                   float64
#  283  (fBodyAcc-energy()-Z,)                   float64
#  284  (fBodyAcc-iqr()-X,)                      float64
#  285  (fBodyAcc-iqr()-Y,)                      float64
#  286  (fBodyAcc-iqr()-Z,)                      float64
#  287  (fBodyAcc-entropy()-X,)                  float64
#  288  (fBodyAcc-entropy()-Y,)                  float64
#  289  (fBodyAcc-entropy()-Z,)                  float64
#  290  (fBodyAcc-maxInds-X,)                    float64
#  291  (fBodyAcc-maxInds-Y,)                    float64
#  292  (fBodyAcc-maxInds-Z,)                    float64
#  293  (fBodyAcc-meanFreq()-X,)                 float64
#  294  (fBodyAcc-meanFreq()-Y,)                 float64
#  295  (fBodyAcc-meanFreq()-Z,)                 float64
#  296  (fBodyAcc-skewness()-X,)                 float64
#  297  (fBodyAcc-kurtosis()-X,)                 float64
#  298  (fBodyAcc-skewness()-Y,)                 float64
#  299  (fBodyAcc-kurtosis()-Y,)                 float64
#  300  (fBodyAcc-skewness()-Z,)                 float64
#  301  (fBodyAcc-kurtosis()-Z,)                 float64
#  302  (fBodyAcc-bandsEnergy()-1,8,)            float64
#  303  (fBodyAcc-bandsEnergy()-9,16,)           float64
#  304  (fBodyAcc-bandsEnergy()-17,24,)          float64
#  305  (fBodyAcc-bandsEnergy()-25,32,)          float64
#  306  (fBodyAcc-bandsEnergy()-33,40,)          float64
#  307  (fBodyAcc-bandsEnergy()-41,48,)          float64
#  308  (fBodyAcc-bandsEnergy()-49,56,)          float64
#  309  (fBodyAcc-bandsEnergy()-57,64,)          float64
#  310  (fBodyAcc-bandsEnergy()-1,16,)           float64
#  311  (fBodyAcc-bandsEnergy()-17,32,)          float64
#  312  (fBodyAcc-bandsEnergy()-33,48,)          float64
#  313  (fBodyAcc-bandsEnergy()-49,64,)          float64
#  314  (fBodyAcc-bandsEnergy()-1,24,)           float64
#  315  (fBodyAcc-bandsEnergy()-25,48,)          float64
#  316  (fBodyAcc-bandsEnergy()-1,8,)            float64
#  317  (fBodyAcc-bandsEnergy()-9,16,)           float64
#  318  (fBodyAcc-bandsEnergy()-17,24,)          float64
#  319  (fBodyAcc-bandsEnergy()-25,32,)          float64
#  320  (fBodyAcc-bandsEnergy()-33,40,)          float64
#  321  (fBodyAcc-bandsEnergy()-41,48,)          float64
#  322  (fBodyAcc-bandsEnergy()-49,56,)          float64
#  323  (fBodyAcc-bandsEnergy()-57,64,)          float64
#  324  (fBodyAcc-bandsEnergy()-1,16,)           float64
#  325  (fBodyAcc-bandsEnergy()-17,32,)          float64
#  326  (fBodyAcc-bandsEnergy()-33,48,)          float64
#  327  (fBodyAcc-bandsEnergy()-49,64,)          float64
#  328  (fBodyAcc-bandsEnergy()-1,24,)           float64
#  329  (fBodyAcc-bandsEnergy()-25,48,)          float64
#  330  (fBodyAcc-bandsEnergy()-1,8,)            float64
#  331  (fBodyAcc-bandsEnergy()-9,16,)           float64
#  332  (fBodyAcc-bandsEnergy()-17,24,)          float64
#  333  (fBodyAcc-bandsEnergy()-25,32,)          float64
#  334  (fBodyAcc-bandsEnergy()-33,40,)          float64
#  335  (fBodyAcc-bandsEnergy()-41,48,)          float64
#  336  (fBodyAcc-bandsEnergy()-49,56,)          float64
#  337  (fBodyAcc-bandsEnergy()-57,64,)          float64
#  338  (fBodyAcc-bandsEnergy()-1,16,)           float64
#  339  (fBodyAcc-bandsEnergy()-17,32,)          float64
#  340  (fBodyAcc-bandsEnergy()-33,48,)          float64
#  341  (fBodyAcc-bandsEnergy()-49,64,)          float64
#  342  (fBodyAcc-bandsEnergy()-1,24,)           float64
#  343  (fBodyAcc-bandsEnergy()-25,48,)          float64
#  344  (fBodyAccJerk-mean()-X,)                 float64
#  345  (fBodyAccJerk-mean()-Y,)                 float64
#  346  (fBodyAccJerk-mean()-Z,)                 float64
#  347  (fBodyAccJerk-std()-X,)                  float64
#  348  (fBodyAccJerk-std()-Y,)                  float64
#  349  (fBodyAccJerk-std()-Z,)                  float64
#  350  (fBodyAccJerk-mad()-X,)                  float64
#  351  (fBodyAccJerk-mad()-Y,)                  float64
#  352  (fBodyAccJerk-mad()-Z,)                  float64
#  353  (fBodyAccJerk-max()-X,)                  float64
#  354  (fBodyAccJerk-max()-Y,)                  float64
#  355  (fBodyAccJerk-max()-Z,)                  float64
#  356  (fBodyAccJerk-min()-X,)                  float64
#  357  (fBodyAccJerk-min()-Y,)                  float64
#  358  (fBodyAccJerk-min()-Z,)                  float64
#  359  (fBodyAccJerk-sma(),)                    float64
#  360  (fBodyAccJerk-energy()-X,)               float64
#  361  (fBodyAccJerk-energy()-Y,)               float64
#  362  (fBodyAccJerk-energy()-Z,)               float64
#  363  (fBodyAccJerk-iqr()-X,)                  float64
#  364  (fBodyAccJerk-iqr()-Y,)                  float64
#  365  (fBodyAccJerk-iqr()-Z,)                  float64
#  366  (fBodyAccJerk-entropy()-X,)              float64
#  367  (fBodyAccJerk-entropy()-Y,)              float64
#  368  (fBodyAccJerk-entropy()-Z,)              float64
#  369  (fBodyAccJerk-maxInds-X,)                float64
#  370  (fBodyAccJerk-maxInds-Y,)                float64
#  371  (fBodyAccJerk-maxInds-Z,)                float64
#  372  (fBodyAccJerk-meanFreq()-X,)             float64
#  373  (fBodyAccJerk-meanFreq()-Y,)             float64
#  374  (fBodyAccJerk-meanFreq()-Z,)             float64
#  375  (fBodyAccJerk-skewness()-X,)             float64
#  376  (fBodyAccJerk-kurtosis()-X,)             float64
#  377  (fBodyAccJerk-skewness()-Y,)             float64
#  378  (fBodyAccJerk-kurtosis()-Y,)             float64
#  379  (fBodyAccJerk-skewness()-Z,)             float64
#  380  (fBodyAccJerk-kurtosis()-Z,)             float64
#  381  (fBodyAccJerk-bandsEnergy()-1,8,)        float64
#  382  (fBodyAccJerk-bandsEnergy()-9,16,)       float64
#  383  (fBodyAccJerk-bandsEnergy()-17,24,)      float64
#  384  (fBodyAccJerk-bandsEnergy()-25,32,)      float64
#  385  (fBodyAccJerk-bandsEnergy()-33,40,)      float64
#  386  (fBodyAccJerk-bandsEnergy()-41,48,)      float64
#  387  (fBodyAccJerk-bandsEnergy()-49,56,)      float64
#  388  (fBodyAccJerk-bandsEnergy()-57,64,)      float64
#  389  (fBodyAccJerk-bandsEnergy()-1,16,)       float64
#  390  (fBodyAccJerk-bandsEnergy()-17,32,)      float64
#  391  (fBodyAccJerk-bandsEnergy()-33,48,)      float64
#  392  (fBodyAccJerk-bandsEnergy()-49,64,)      float64
#  393  (fBodyAccJerk-bandsEnergy()-1,24,)       float64
#  394  (fBodyAccJerk-bandsEnergy()-25,48,)      float64
#  395  (fBodyAccJerk-bandsEnergy()-1,8,)        float64
#  396  (fBodyAccJerk-bandsEnergy()-9,16,)       float64
#  397  (fBodyAccJerk-bandsEnergy()-17,24,)      float64
#  398  (fBodyAccJerk-bandsEnergy()-25,32,)      float64
#  399  (fBodyAccJerk-bandsEnergy()-33,40,)      float64
#  400  (fBodyAccJerk-bandsEnergy()-41,48,)      float64
#  401  (fBodyAccJerk-bandsEnergy()-49,56,)      float64
#  402  (fBodyAccJerk-bandsEnergy()-57,64,)      float64
#  403  (fBodyAccJerk-bandsEnergy()-1,16,)       float64
#  404  (fBodyAccJerk-bandsEnergy()-17,32,)      float64
#  405  (fBodyAccJerk-bandsEnergy()-33,48,)      float64
#  406  (fBodyAccJerk-bandsEnergy()-49,64,)      float64
#  407  (fBodyAccJerk-bandsEnergy()-1,24,)       float64
#  408  (fBodyAccJerk-bandsEnergy()-25,48,)      float64
#  409  (fBodyAccJerk-bandsEnergy()-1,8,)        float64
#  410  (fBodyAccJerk-bandsEnergy()-9,16,)       float64
#  411  (fBodyAccJerk-bandsEnergy()-17,24,)      float64
#  412  (fBodyAccJerk-bandsEnergy()-25,32,)      float64
#  413  (fBodyAccJerk-bandsEnergy()-33,40,)      float64
#  414  (fBodyAccJerk-bandsEnergy()-41,48,)      float64
#  415  (fBodyAccJerk-bandsEnergy()-49,56,)      float64
#  416  (fBodyAccJerk-bandsEnergy()-57,64,)      float64
#  417  (fBodyAccJerk-bandsEnergy()-1,16,)       float64
#  418  (fBodyAccJerk-bandsEnergy()-17,32,)      float64
#  419  (fBodyAccJerk-bandsEnergy()-33,48,)      float64
#  420  (fBodyAccJerk-bandsEnergy()-49,64,)      float64
#  421  (fBodyAccJerk-bandsEnergy()-1,24,)       float64
#  422  (fBodyAccJerk-bandsEnergy()-25,48,)      float64
#  423  (fBodyGyro-mean()-X,)                    float64
#  424  (fBodyGyro-mean()-Y,)                    float64
#  425  (fBodyGyro-mean()-Z,)                    float64
#  426  (fBodyGyro-std()-X,)                     float64
#  427  (fBodyGyro-std()-Y,)                     float64
#  428  (fBodyGyro-std()-Z,)                     float64
#  429  (fBodyGyro-mad()-X,)                     float64
#  430  (fBodyGyro-mad()-Y,)                     float64
#  431  (fBodyGyro-mad()-Z,)                     float64
#  432  (fBodyGyro-max()-X,)                     float64
#  433  (fBodyGyro-max()-Y,)                     float64
#  434  (fBodyGyro-max()-Z,)                     float64
#  435  (fBodyGyro-min()-X,)                     float64
#  436  (fBodyGyro-min()-Y,)                     float64
#  437  (fBodyGyro-min()-Z,)                     float64
#  438  (fBodyGyro-sma(),)                       float64
#  439  (fBodyGyro-energy()-X,)                  float64
#  440  (fBodyGyro-energy()-Y,)                  float64
#  441  (fBodyGyro-energy()-Z,)                  float64
#  442  (fBodyGyro-iqr()-X,)                     float64
#  443  (fBodyGyro-iqr()-Y,)                     float64
#  444  (fBodyGyro-iqr()-Z,)                     float64
#  445  (fBodyGyro-entropy()-X,)                 float64
#  446  (fBodyGyro-entropy()-Y,)                 float64
#  447  (fBodyGyro-entropy()-Z,)                 float64
#  448  (fBodyGyro-maxInds-X,)                   float64
#  449  (fBodyGyro-maxInds-Y,)                   float64
#  450  (fBodyGyro-maxInds-Z,)                   float64
#  451  (fBodyGyro-meanFreq()-X,)                float64
#  452  (fBodyGyro-meanFreq()-Y,)                float64
#  453  (fBodyGyro-meanFreq()-Z,)                float64
#  454  (fBodyGyro-skewness()-X,)                float64
#  455  (fBodyGyro-kurtosis()-X,)                float64
#  456  (fBodyGyro-skewness()-Y,)                float64
#  457  (fBodyGyro-kurtosis()-Y,)                float64
#  458  (fBodyGyro-skewness()-Z,)                float64
#  459  (fBodyGyro-kurtosis()-Z,)                float64
#  460  (fBodyGyro-bandsEnergy()-1,8,)           float64
#  461  (fBodyGyro-bandsEnergy()-9,16,)          float64
#  462  (fBodyGyro-bandsEnergy()-17,24,)         float64
#  463  (fBodyGyro-bandsEnergy()-25,32,)         float64
#  464  (fBodyGyro-bandsEnergy()-33,40,)         float64
#  465  (fBodyGyro-bandsEnergy()-41,48,)         float64
#  466  (fBodyGyro-bandsEnergy()-49,56,)         float64
#  467  (fBodyGyro-bandsEnergy()-57,64,)         float64
#  468  (fBodyGyro-bandsEnergy()-1,16,)          float64
#  469  (fBodyGyro-bandsEnergy()-17,32,)         float64
#  470  (fBodyGyro-bandsEnergy()-33,48,)         float64
#  471  (fBodyGyro-bandsEnergy()-49,64,)         float64
#  472  (fBodyGyro-bandsEnergy()-1,24,)          float64
#  473  (fBodyGyro-bandsEnergy()-25,48,)         float64
#  474  (fBodyGyro-bandsEnergy()-1,8,)           float64
#  475  (fBodyGyro-bandsEnergy()-9,16,)          float64
#  476  (fBodyGyro-bandsEnergy()-17,24,)         float64
#  477  (fBodyGyro-bandsEnergy()-25,32,)         float64
#  478  (fBodyGyro-bandsEnergy()-33,40,)         float64
#  479  (fBodyGyro-bandsEnergy()-41,48,)         float64
#  480  (fBodyGyro-bandsEnergy()-49,56,)         float64
#  481  (fBodyGyro-bandsEnergy()-57,64,)         float64
#  482  (fBodyGyro-bandsEnergy()-1,16,)          float64
#  483  (fBodyGyro-bandsEnergy()-17,32,)         float64
#  484  (fBodyGyro-bandsEnergy()-33,48,)         float64
#  485  (fBodyGyro-bandsEnergy()-49,64,)         float64
#  486  (fBodyGyro-bandsEnergy()-1,24,)          float64
#  487  (fBodyGyro-bandsEnergy()-25,48,)         float64
#  488  (fBodyGyro-bandsEnergy()-1,8,)           float64
#  489  (fBodyGyro-bandsEnergy()-9,16,)          float64
#  490  (fBodyGyro-bandsEnergy()-17,24,)         float64
#  491  (fBodyGyro-bandsEnergy()-25,32,)         float64
#  492  (fBodyGyro-bandsEnergy()-33,40,)         float64
#  493  (fBodyGyro-bandsEnergy()-41,48,)         float64
#  494  (fBodyGyro-bandsEnergy()-49,56,)         float64
#  495  (fBodyGyro-bandsEnergy()-57,64,)         float64
#  496  (fBodyGyro-bandsEnergy()-1,16,)          float64
#  497  (fBodyGyro-bandsEnergy()-17,32,)         float64
#  498  (fBodyGyro-bandsEnergy()-33,48,)         float64
#  499  (fBodyGyro-bandsEnergy()-49,64,)         float64
#  500  (fBodyGyro-bandsEnergy()-1,24,)          float64
#  501  (fBodyGyro-bandsEnergy()-25,48,)         float64
#  502  (fBodyAccMag-mean(),)                    float64
#  503  (fBodyAccMag-std(),)                     float64
#  504  (fBodyAccMag-mad(),)                     float64
#  505  (fBodyAccMag-max(),)                     float64
#  506  (fBodyAccMag-min(),)                     float64
#  507  (fBodyAccMag-sma(),)                     float64
#  508  (fBodyAccMag-energy(),)                  float64
#  509  (fBodyAccMag-iqr(),)                     float64
#  510  (fBodyAccMag-entropy(),)                 float64
#  511  (fBodyAccMag-maxInds,)                   float64
#  512  (fBodyAccMag-meanFreq(),)                float64
#  513  (fBodyAccMag-skewness(),)                float64
#  514  (fBodyAccMag-kurtosis(),)                float64
#  515  (fBodyBodyAccJerkMag-mean(),)            float64
#  516  (fBodyBodyAccJerkMag-std(),)             float64
#  517  (fBodyBodyAccJerkMag-mad(),)             float64
#  518  (fBodyBodyAccJerkMag-max(),)             float64
#  519  (fBodyBodyAccJerkMag-min(),)             float64
#  520  (fBodyBodyAccJerkMag-sma(),)             float64
#  521  (fBodyBodyAccJerkMag-energy(),)          float64
#  522  (fBodyBodyAccJerkMag-iqr(),)             float64
#  523  (fBodyBodyAccJerkMag-entropy(),)         float64
#  524  (fBodyBodyAccJerkMag-maxInds,)           float64
#  525  (fBodyBodyAccJerkMag-meanFreq(),)        float64
#  526  (fBodyBodyAccJerkMag-skewness(),)        float64
#  527  (fBodyBodyAccJerkMag-kurtosis(),)        float64
#  528  (fBodyBodyGyroMag-mean(),)               float64
#  529  (fBodyBodyGyroMag-std(),)                float64
#  530  (fBodyBodyGyroMag-mad(),)                float64
#  531  (fBodyBodyGyroMag-max(),)                float64
#  532  (fBodyBodyGyroMag-min(),)                float64
#  533  (fBodyBodyGyroMag-sma(),)                float64
#  534  (fBodyBodyGyroMag-energy(),)             float64
#  535  (fBodyBodyGyroMag-iqr(),)                float64
#  536  (fBodyBodyGyroMag-entropy(),)            float64
#  537  (fBodyBodyGyroMag-maxInds,)              float64
#  538  (fBodyBodyGyroMag-meanFreq(),)           float64
#  539  (fBodyBodyGyroMag-skewness(),)           float64
#  540  (fBodyBodyGyroMag-kurtosis(),)           float64
#  541  (fBodyBodyGyroJerkMag-mean(),)           float64
#  542  (fBodyBodyGyroJerkMag-std(),)            float64
#  543  (fBodyBodyGyroJerkMag-mad(),)            float64
#  544  (fBodyBodyGyroJerkMag-max(),)            float64
#  545  (fBodyBodyGyroJerkMag-min(),)            float64
#  546  (fBodyBodyGyroJerkMag-sma(),)            float64
#  547  (fBodyBodyGyroJerkMag-energy(),)         float64
#  548  (fBodyBodyGyroJerkMag-iqr(),)            float64
#  549  (fBodyBodyGyroJerkMag-entropy(),)        float64
#  550  (fBodyBodyGyroJerkMag-maxInds,)          float64
#  551  (fBodyBodyGyroJerkMag-meanFreq(),)       float64
#  552  (fBodyBodyGyroJerkMag-skewness(),)       float64
#  553  (fBodyBodyGyroJerkMag-kurtosis(),)       float64
#  554  (angle(tBodyAccMean,gravity),)           float64
#  555  (angle(tBodyAccJerkMean),gravityMean),)  float64
#  556  (angle(tBodyGyroMean,gravityMean),)      float64
#  557  (angle(tBodyGyroJerkMean,gravityMean),)  float64
#  558  (angle(X,gravityMean),)                  float64
#  559  (angle(Y,gravityMean),)                  float64
#  560  (angle(Z,gravityMean),)                  float64
#  561  (subjectid,)                             int64
#  562  (activity,)                              int64
#  563  (activityname,)                          object
# dtypes: float64(561), int64(2), object(1)
# memory usage: 12.7+ MB

# %%
testdf.describe(include='all')
# Out:
#        tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# count        2947.000000       2947.000000       2947.000000      2947.000000
# unique               NaN               NaN               NaN              NaN
# top                  NaN               NaN               NaN              NaN
# freq                 NaN               NaN               NaN              NaN
# mean            0.273996         -0.017863         -0.108386        -0.613635
# std             0.060570          0.025745          0.042747         0.412597
# min            -0.592004         -0.362884         -0.576184        -0.999606
# 25%             0.262075         -0.024961         -0.121162        -0.990914
# 50%             0.277113         -0.016967         -0.108458        -0.931214
# 75%             0.288097         -0.010143         -0.097123        -0.267395
# max             0.671887          0.246106          0.494114         0.465299
#
#        tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# count       2947.000000      2947.000000      2947.000000      2947.000000
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean          -0.508330        -0.633797        -0.641278        -0.522676
# std            0.494269         0.362699         0.385199         0.479899
# min           -1.000000        -0.998955        -0.999417        -0.999914
# 25%           -0.973664        -0.976122        -0.992333        -0.974131
# 50%           -0.790972        -0.827534        -0.937664        -0.799907
# 75%           -0.105919        -0.311432        -0.321719        -0.133488
# max            1.000000         0.489703         0.439657         1.000000
#
#        tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# count       2947.000000      2947.000000  ...                 2947.000000
# unique              NaN              NaN  ...                         NaN
# top                 NaN              NaN  ...                         NaN
# freq                NaN              NaN  ...                         NaN
# mean          -0.637038        -0.462063  ...                    0.005264
# std            0.357753         0.523916  ...                    0.336147
# min           -0.998899        -0.952357  ...                   -1.000000
# 25%           -0.975352        -0.934447  ...                   -0.130541
# 50%           -0.817005        -0.852659  ...                    0.005188
# 75%           -0.322771        -0.009965  ...                    0.146200
# max            0.427958         0.786436  ...                    0.998898
#
#        angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# count                           2947.000000                      2947.000000
# unique                                  NaN                              NaN
# top                                     NaN                              NaN
# freq                                    NaN                              NaN
# mean                               0.003799                         0.040029
# std                                0.445077                         0.634989
# min                               -0.993402                        -0.998898
# 25%                               -0.282600                        -0.518924
# 50%                                0.006767                         0.047113
# 75%                                0.288113                         0.622151
# max                                0.986347                         1.000000
#
#        angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# count                           2947.000000          2947.000000
# unique                                  NaN                  NaN
# top                                     NaN                  NaN
# freq                                    NaN                  NaN
# mean                              -0.017298            -0.513923
# std                                0.501311             0.509205
# min                               -0.991096            -0.984195
# 25%                               -0.428375            -0.829722
# 50%                               -0.026726            -0.729648
# 75%                                0.394387            -0.545939
# max                                1.000000             0.833180
#
#        angle(Y,gravityMean) angle(Z,gravityMean)    subjectid     activity  \
# count           2947.000000          2947.000000  2947.000000  2947.000000
# unique                  NaN                  NaN          NaN          NaN
# top                     NaN                  NaN          NaN          NaN
# freq                    NaN                  NaN          NaN          NaN
# mean               0.074886            -0.048720    12.986427     3.577876
# std                0.324300             0.241467     6.950984     1.740348
# min               -0.913704            -0.949228     2.000000     1.000000
# 25%                0.022140            -0.098485     9.000000     2.000000
# 50%                0.181563            -0.010671    12.000000     4.000000
# 75%                0.260252             0.092373    18.000000     5.000000
# max                1.000000             0.973113    24.000000     6.000000
#
#        activityname
# count          2947
# unique            6
# top          LAYING
# freq            537
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN
#
# [11 rows x 564 columns]

# %%
#Null values in test set
testdf.isna().sum().sum()
# Out:
# 0

# %%
##EDA

# %%
#Check for Imbalance data wrt target column (Y-TRAIN)
fig = plt.figure(figsize=(12,6))
ax = fig.add_axes([0,0,1,1])
plt.title("Number of record per activity")
plt.hist(traindf['activityname'])
plt.ylabel = 'Number of records'
plt.xlabel =''
plt.xticks(rotation=45)
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
ax = fig.add_axes([0,0,1,1])
plt.title("Frequency of activity done by each subjects")
plt.hist(traindf['subjectid'])
plt.ylabel = 'Frequency'
plt.xlabel =''
plt.xticks(rotation=45)
plt.show()

# %%
#Remove special characters from feature names
li = traindf.columns
#print(li[-1][0])
newcols = []
for i in range(len(li)):
    temp = str(li[i][0])
    temp = temp.replace('[','')
    temp = temp.replace(']','')
    temp = temp.replace('(','')
    temp = temp.replace(')','')
    temp = temp.replace('-','')
    temp = temp.replace(',','')
    print(f'appending {temp}') #just to verify
    newcols.append(temp)
# Out:
# appending tBodyAccmeanX
# appending tBodyAccmeanY
# appending tBodyAccmeanZ
# appending tBodyAccstdX
# appending tBodyAccstdY
# appending tBodyAccstdZ
# appending tBodyAccmadX
# appending tBodyAccmadY
# appending tBodyAccmadZ
# appending tBodyAccmaxX
# appending tBodyAccmaxY
# appending tBodyAccmaxZ
# appending tBodyAccminX
# appending tBodyAccminY
# appending tBodyAccminZ
# appending tBodyAccsma
# appending tBodyAccenergyX
# appending tBodyAccenergyY
# appending tBodyAccenergyZ
# appending tBodyAcciqrX
# appending tBodyAcciqrY
# appending tBodyAcciqrZ
# appending tBodyAccentropyX
# appending tBodyAccentropyY
# appending tBodyAccentropyZ
# appending tBodyAccarCoeffX1
# appending tBodyAccarCoeffX2
# appending tBodyAccarCoeffX3
# appending tBodyAccarCoeffX4
# appending tBodyAccarCoeffY1
# appending tBodyAccarCoeffY2
# appending tBodyAccarCoeffY3
# appending tBodyAccarCoeffY4
# appending tBodyAccarCoeffZ1
# appending tBodyAccarCoeffZ2
# appending tBodyAccarCoeffZ3
# appending tBodyAccarCoeffZ4
# appending tBodyAcccorrelationXY
# appending tBodyAcccorrelationXZ
# appending tBodyAcccorrelationYZ
# appending tGravityAccmeanX
# appending tGravityAccmeanY
# appending tGravityAccmeanZ
# appending tGravityAccstdX
# appending tGravityAccstdY
# appending tGravityAccstdZ
# appending tGravityAccmadX
# appending tGravityAccmadY
# appending tGravityAccmadZ
# appending tGravityAccmaxX
# appending tGravityAccmaxY
# appending tGravityAccmaxZ
# appending tGravityAccminX
# appending tGravityAccminY
# appending tGravityAccminZ
# appending tGravityAccsma
# appending tGravityAccenergyX
# appending tGravityAccenergyY
# appending tGravityAccenergyZ
# appending tGravityAcciqrX
# appending tGravityAcciqrY
# appending tGravityAcciqrZ
# appending tGravityAccentropyX
# appending tGravityAccentropyY
# appending tGravityAccentropyZ
# appending tGravityAccarCoeffX1
# appending tGravityAccarCoeffX2
# appending tGravityAccarCoeffX3
# appending tGravityAccarCoeffX4
# appending tGravityAccarCoeffY1
# appending tGravityAccarCoeffY2
# appending tGravityAccarCoeffY3
# appending tGravityAccarCoeffY4
# appending tGravityAccarCoeffZ1
# appending tGravityAccarCoeffZ2
# appending tGravityAccarCoeffZ3
# appending tGravityAccarCoeffZ4
# appending tGravityAcccorrelationXY
# appending tGravityAcccorrelationXZ
# appending tGravityAcccorrelationYZ
# appending tBodyAccJerkmeanX
# appending tBodyAccJerkmeanY
# appending tBodyAccJerkmeanZ
# appending tBodyAccJerkstdX
# appending tBodyAccJerkstdY
# appending tBodyAccJerkstdZ
# appending tBodyAccJerkmadX
# appending tBodyAccJerkmadY
# appending tBodyAccJerkmadZ
# appending tBodyAccJerkmaxX
# appending tBodyAccJerkmaxY
# appending tBodyAccJerkmaxZ
# appending tBodyAccJerkminX
# appending tBodyAccJerkminY
# appending tBodyAccJerkminZ
# appending tBodyAccJerksma
# appending tBodyAccJerkenergyX
# appending tBodyAccJerkenergyY
# appending tBodyAccJerkenergyZ
# appending tBodyAccJerkiqrX
# appending tBodyAccJerkiqrY
# appending tBodyAccJerkiqrZ
# appending tBodyAccJerkentropyX
# appending tBodyAccJerkentropyY
# appending tBodyAccJerkentropyZ
# appending tBodyAccJerkarCoeffX1
# appending tBodyAccJerkarCoeffX2
# appending tBodyAccJerkarCoeffX3
# appending tBodyAccJerkarCoeffX4
# appending tBodyAccJerkarCoeffY1
# appending tBodyAccJerkarCoeffY2
# appending tBodyAccJerkarCoeffY3
# appending tBodyAccJerkarCoeffY4
# appending tBodyAccJerkarCoeffZ1
# appending tBodyAccJerkarCoeffZ2
# appending tBodyAccJerkarCoeffZ3
# appending tBodyAccJerkarCoeffZ4
# appending tBodyAccJerkcorrelationXY
# appending tBodyAccJerkcorrelationXZ
# appending tBodyAccJerkcorrelationYZ
# appending tBodyGyromeanX
# appending tBodyGyromeanY
# appending tBodyGyromeanZ
# appending tBodyGyrostdX
# appending tBodyGyrostdY
# appending tBodyGyrostdZ
# appending tBodyGyromadX
# appending tBodyGyromadY
# appending tBodyGyromadZ
# appending tBodyGyromaxX
# appending tBodyGyromaxY
# appending tBodyGyromaxZ
# appending tBodyGyrominX
# appending tBodyGyrominY
# appending tBodyGyrominZ
# appending tBodyGyrosma
# appending tBodyGyroenergyX
# appending tBodyGyroenergyY
# appending tBodyGyroenergyZ
# appending tBodyGyroiqrX
# appending tBodyGyroiqrY
# appending tBodyGyroiqrZ
# appending tBodyGyroentropyX
# appending tBodyGyroentropyY
# appending tBodyGyroentropyZ
# appending tBodyGyroarCoeffX1
# appending tBodyGyroarCoeffX2
# appending tBodyGyroarCoeffX3
# appending tBodyGyroarCoeffX4
# appending tBodyGyroarCoeffY1
# appending tBodyGyroarCoeffY2
# appending tBodyGyroarCoeffY3
# appending tBodyGyroarCoeffY4
# appending tBodyGyroarCoeffZ1
# appending tBodyGyroarCoeffZ2
# appending tBodyGyroarCoeffZ3
# appending tBodyGyroarCoeffZ4
# appending tBodyGyrocorrelationXY
# appending tBodyGyrocorrelationXZ
# appending tBodyGyrocorrelationYZ
# appending tBodyGyroJerkmeanX
# appending tBodyGyroJerkmeanY
# appending tBodyGyroJerkmeanZ
# appending tBodyGyroJerkstdX
# appending tBodyGyroJerkstdY
# appending tBodyGyroJerkstdZ
# appending tBodyGyroJerkmadX
# appending tBodyGyroJerkmadY
# appending tBodyGyroJerkmadZ
# appending tBodyGyroJerkmaxX
# appending tBodyGyroJerkmaxY
# appending tBodyGyroJerkmaxZ
# appending tBodyGyroJerkminX
# appending tBodyGyroJerkminY
# appending tBodyGyroJerkminZ
# appending tBodyGyroJerksma
# appending tBodyGyroJerkenergyX
# appending tBodyGyroJerkenergyY
# appending tBodyGyroJerkenergyZ
# appending tBodyGyroJerkiqrX
# appending tBodyGyroJerkiqrY
# appending tBodyGyroJerkiqrZ
# appending tBodyGyroJerkentropyX
# appending tBodyGyroJerkentropyY
# appending tBodyGyroJerkentropyZ
# appending tBodyGyroJerkarCoeffX1
# appending tBodyGyroJerkarCoeffX2
# appending tBodyGyroJerkarCoeffX3
# appending tBodyGyroJerkarCoeffX4
# appending tBodyGyroJerkarCoeffY1
# appending tBodyGyroJerkarCoeffY2
# appending tBodyGyroJerkarCoeffY3
# appending tBodyGyroJerkarCoeffY4
# appending tBodyGyroJerkarCoeffZ1
# appending tBodyGyroJerkarCoeffZ2
# appending tBodyGyroJerkarCoeffZ3
# appending tBodyGyroJerkarCoeffZ4
# appending tBodyGyroJerkcorrelationXY
# appending tBodyGyroJerkcorrelationXZ
# appending tBodyGyroJerkcorrelationYZ
# appending tBodyAccMagmean
# appending tBodyAccMagstd
# appending tBodyAccMagmad
# appending tBodyAccMagmax
# appending tBodyAccMagmin
# appending tBodyAccMagsma
# appending tBodyAccMagenergy
# appending tBodyAccMagiqr
# appending tBodyAccMagentropy
# appending tBodyAccMagarCoeff1
# appending tBodyAccMagarCoeff2
# appending tBodyAccMagarCoeff3
# appending tBodyAccMagarCoeff4
# appending tGravityAccMagmean
# appending tGravityAccMagstd
# appending tGravityAccMagmad
# appending tGravityAccMagmax
# appending tGravityAccMagmin
# appending tGravityAccMagsma
# appending tGravityAccMagenergy
# appending tGravityAccMagiqr
# appending tGravityAccMagentropy
# appending tGravityAccMagarCoeff1
# appending tGravityAccMagarCoeff2
# appending tGravityAccMagarCoeff3
# appending tGravityAccMagarCoeff4
# appending tBodyAccJerkMagmean
# appending tBodyAccJerkMagstd
# appending tBodyAccJerkMagmad
# appending tBodyAccJerkMagmax
# appending tBodyAccJerkMagmin
# appending tBodyAccJerkMagsma
# appending tBodyAccJerkMagenergy
# appending tBodyAccJerkMagiqr
# appending tBodyAccJerkMagentropy
# appending tBodyAccJerkMagarCoeff1
# appending tBodyAccJerkMagarCoeff2
# appending tBodyAccJerkMagarCoeff3
# appending tBodyAccJerkMagarCoeff4
# appending tBodyGyroMagmean
# appending tBodyGyroMagstd
# appending tBodyGyroMagmad
# appending tBodyGyroMagmax
# appending tBodyGyroMagmin
# appending tBodyGyroMagsma
# appending tBodyGyroMagenergy
# appending tBodyGyroMagiqr
# appending tBodyGyroMagentropy
# appending tBodyGyroMagarCoeff1
# appending tBodyGyroMagarCoeff2
# appending tBodyGyroMagarCoeff3
# appending tBodyGyroMagarCoeff4
# appending tBodyGyroJerkMagmean
# appending tBodyGyroJerkMagstd
# appending tBodyGyroJerkMagmad
# appending tBodyGyroJerkMagmax
# appending tBodyGyroJerkMagmin
# appending tBodyGyroJerkMagsma
# appending tBodyGyroJerkMagenergy
# appending tBodyGyroJerkMagiqr
# appending tBodyGyroJerkMagentropy
# appending tBodyGyroJerkMagarCoeff1
# appending tBodyGyroJerkMagarCoeff2
# appending tBodyGyroJerkMagarCoeff3
# appending tBodyGyroJerkMagarCoeff4
# appending fBodyAccmeanX
# appending fBodyAccmeanY
# appending fBodyAccmeanZ
# appending fBodyAccstdX
# appending fBodyAccstdY
# appending fBodyAccstdZ
# appending fBodyAccmadX
# appending fBodyAccmadY
# appending fBodyAccmadZ
# appending fBodyAccmaxX
# appending fBodyAccmaxY
# appending fBodyAccmaxZ
# appending fBodyAccminX
# appending fBodyAccminY
# appending fBodyAccminZ
# appending fBodyAccsma
# appending fBodyAccenergyX
# appending fBodyAccenergyY
# appending fBodyAccenergyZ
# appending fBodyAcciqrX
# appending fBodyAcciqrY
# appending fBodyAcciqrZ
# appending fBodyAccentropyX
# appending fBodyAccentropyY
# appending fBodyAccentropyZ
# appending fBodyAccmaxIndsX
# appending fBodyAccmaxIndsY
# appending fBodyAccmaxIndsZ
# appending fBodyAccmeanFreqX
# appending fBodyAccmeanFreqY
# appending fBodyAccmeanFreqZ
# appending fBodyAccskewnessX
# appending fBodyAcckurtosisX
# appending fBodyAccskewnessY
# appending fBodyAcckurtosisY
# appending fBodyAccskewnessZ
# appending fBodyAcckurtosisZ
# appending fBodyAccbandsEnergy18
# appending fBodyAccbandsEnergy916
# appending fBodyAccbandsEnergy1724
# appending fBodyAccbandsEnergy2532
# appending fBodyAccbandsEnergy3340
# appending fBodyAccbandsEnergy4148
# appending fBodyAccbandsEnergy4956
# appending fBodyAccbandsEnergy5764
# appending fBodyAccbandsEnergy116
# appending fBodyAccbandsEnergy1732
# appending fBodyAccbandsEnergy3348
# appending fBodyAccbandsEnergy4964
# appending fBodyAccbandsEnergy124
# appending fBodyAccbandsEnergy2548
# appending fBodyAccbandsEnergy18
# appending fBodyAccbandsEnergy916
# appending fBodyAccbandsEnergy1724
# appending fBodyAccbandsEnergy2532
# appending fBodyAccbandsEnergy3340
# appending fBodyAccbandsEnergy4148
# appending fBodyAccbandsEnergy4956
# appending fBodyAccbandsEnergy5764
# appending fBodyAccbandsEnergy116
# appending fBodyAccbandsEnergy1732
# appending fBodyAccbandsEnergy3348
# appending fBodyAccbandsEnergy4964
# appending fBodyAccbandsEnergy124
# appending fBodyAccbandsEnergy2548
# appending fBodyAccbandsEnergy18
# appending fBodyAccbandsEnergy916
# appending fBodyAccbandsEnergy1724
# appending fBodyAccbandsEnergy2532
# appending fBodyAccbandsEnergy3340
# appending fBodyAccbandsEnergy4148
# appending fBodyAccbandsEnergy4956
# appending fBodyAccbandsEnergy5764
# appending fBodyAccbandsEnergy116
# appending fBodyAccbandsEnergy1732
# appending fBodyAccbandsEnergy3348
# appending fBodyAccbandsEnergy4964
# appending fBodyAccbandsEnergy124
# appending fBodyAccbandsEnergy2548
# appending fBodyAccJerkmeanX
# appending fBodyAccJerkmeanY
# appending fBodyAccJerkmeanZ
# appending fBodyAccJerkstdX
# appending fBodyAccJerkstdY
# appending fBodyAccJerkstdZ
# appending fBodyAccJerkmadX
# appending fBodyAccJerkmadY
# appending fBodyAccJerkmadZ
# appending fBodyAccJerkmaxX
# appending fBodyAccJerkmaxY
# appending fBodyAccJerkmaxZ
# appending fBodyAccJerkminX
# appending fBodyAccJerkminY
# appending fBodyAccJerkminZ
# appending fBodyAccJerksma
# appending fBodyAccJerkenergyX
# appending fBodyAccJerkenergyY
# appending fBodyAccJerkenergyZ
# appending fBodyAccJerkiqrX
# appending fBodyAccJerkiqrY
# appending fBodyAccJerkiqrZ
# appending fBodyAccJerkentropyX
# appending fBodyAccJerkentropyY
# appending fBodyAccJerkentropyZ
# appending fBodyAccJerkmaxIndsX
# appending fBodyAccJerkmaxIndsY
# appending fBodyAccJerkmaxIndsZ
# appending fBodyAccJerkmeanFreqX
# appending fBodyAccJerkmeanFreqY
# appending fBodyAccJerkmeanFreqZ
# appending fBodyAccJerkskewnessX
# appending fBodyAccJerkkurtosisX
# appending fBodyAccJerkskewnessY
# appending fBodyAccJerkkurtosisY
# appending fBodyAccJerkskewnessZ
# appending fBodyAccJerkkurtosisZ
# appending fBodyAccJerkbandsEnergy18
# appending fBodyAccJerkbandsEnergy916
# appending fBodyAccJerkbandsEnergy1724
# appending fBodyAccJerkbandsEnergy2532
# appending fBodyAccJerkbandsEnergy3340
# appending fBodyAccJerkbandsEnergy4148
# appending fBodyAccJerkbandsEnergy4956
# appending fBodyAccJerkbandsEnergy5764
# appending fBodyAccJerkbandsEnergy116
# appending fBodyAccJerkbandsEnergy1732
# appending fBodyAccJerkbandsEnergy3348
# appending fBodyAccJerkbandsEnergy4964
# appending fBodyAccJerkbandsEnergy124
# appending fBodyAccJerkbandsEnergy2548
# appending fBodyAccJerkbandsEnergy18
# appending fBodyAccJerkbandsEnergy916
# appending fBodyAccJerkbandsEnergy1724
# appending fBodyAccJerkbandsEnergy2532
# appending fBodyAccJerkbandsEnergy3340
# appending fBodyAccJerkbandsEnergy4148
# appending fBodyAccJerkbandsEnergy4956
# appending fBodyAccJerkbandsEnergy5764
# appending fBodyAccJerkbandsEnergy116
# appending fBodyAccJerkbandsEnergy1732
# appending fBodyAccJerkbandsEnergy3348
# appending fBodyAccJerkbandsEnergy4964
# appending fBodyAccJerkbandsEnergy124
# appending fBodyAccJerkbandsEnergy2548
# appending fBodyAccJerkbandsEnergy18
# appending fBodyAccJerkbandsEnergy916
# appending fBodyAccJerkbandsEnergy1724
# appending fBodyAccJerkbandsEnergy2532
# appending fBodyAccJerkbandsEnergy3340
# appending fBodyAccJerkbandsEnergy4148
# appending fBodyAccJerkbandsEnergy4956
# appending fBodyAccJerkbandsEnergy5764
# appending fBodyAccJerkbandsEnergy116
# appending fBodyAccJerkbandsEnergy1732
# appending fBodyAccJerkbandsEnergy3348
# appending fBodyAccJerkbandsEnergy4964
# appending fBodyAccJerkbandsEnergy124
# appending fBodyAccJerkbandsEnergy2548
# appending fBodyGyromeanX
# appending fBodyGyromeanY
# appending fBodyGyromeanZ
# appending fBodyGyrostdX
# appending fBodyGyrostdY
# appending fBodyGyrostdZ
# appending fBodyGyromadX
# appending fBodyGyromadY
# appending fBodyGyromadZ
# appending fBodyGyromaxX
# appending fBodyGyromaxY
# appending fBodyGyromaxZ
# appending fBodyGyrominX
# appending fBodyGyrominY
# appending fBodyGyrominZ
# appending fBodyGyrosma
# appending fBodyGyroenergyX
# appending fBodyGyroenergyY
# appending fBodyGyroenergyZ
# appending fBodyGyroiqrX
# appending fBodyGyroiqrY
# appending fBodyGyroiqrZ
# appending fBodyGyroentropyX
# appending fBodyGyroentropyY
# appending fBodyGyroentropyZ
# appending fBodyGyromaxIndsX
# appending fBodyGyromaxIndsY
# appending fBodyGyromaxIndsZ
# appending fBodyGyromeanFreqX
# appending fBodyGyromeanFreqY
# appending fBodyGyromeanFreqZ
# appending fBodyGyroskewnessX
# appending fBodyGyrokurtosisX
# appending fBodyGyroskewnessY
# appending fBodyGyrokurtosisY
# appending fBodyGyroskewnessZ
# appending fBodyGyrokurtosisZ
# appending fBodyGyrobandsEnergy18
# appending fBodyGyrobandsEnergy916
# appending fBodyGyrobandsEnergy1724
# appending fBodyGyrobandsEnergy2532
# appending fBodyGyrobandsEnergy3340
# appending fBodyGyrobandsEnergy4148
# appending fBodyGyrobandsEnergy4956
# appending fBodyGyrobandsEnergy5764
# appending fBodyGyrobandsEnergy116
# appending fBodyGyrobandsEnergy1732
# appending fBodyGyrobandsEnergy3348
# appending fBodyGyrobandsEnergy4964
# appending fBodyGyrobandsEnergy124
# appending fBodyGyrobandsEnergy2548
# appending fBodyGyrobandsEnergy18
# appending fBodyGyrobandsEnergy916
# appending fBodyGyrobandsEnergy1724
# appending fBodyGyrobandsEnergy2532
# appending fBodyGyrobandsEnergy3340
# appending fBodyGyrobandsEnergy4148
# appending fBodyGyrobandsEnergy4956
# appending fBodyGyrobandsEnergy5764
# appending fBodyGyrobandsEnergy116
# appending fBodyGyrobandsEnergy1732
# appending fBodyGyrobandsEnergy3348
# appending fBodyGyrobandsEnergy4964
# appending fBodyGyrobandsEnergy124
# appending fBodyGyrobandsEnergy2548
# appending fBodyGyrobandsEnergy18
# appending fBodyGyrobandsEnergy916
# appending fBodyGyrobandsEnergy1724
# appending fBodyGyrobandsEnergy2532
# appending fBodyGyrobandsEnergy3340
# appending fBodyGyrobandsEnergy4148
# appending fBodyGyrobandsEnergy4956
# appending fBodyGyrobandsEnergy5764
# appending fBodyGyrobandsEnergy116
# appending fBodyGyrobandsEnergy1732
# appending fBodyGyrobandsEnergy3348
# appending fBodyGyrobandsEnergy4964
# appending fBodyGyrobandsEnergy124
# appending fBodyGyrobandsEnergy2548
# appending fBodyAccMagmean
# appending fBodyAccMagstd
# appending fBodyAccMagmad
# appending fBodyAccMagmax
# appending fBodyAccMagmin
# appending fBodyAccMagsma
# appending fBodyAccMagenergy
# appending fBodyAccMagiqr
# appending fBodyAccMagentropy
# appending fBodyAccMagmaxInds
# appending fBodyAccMagmeanFreq
# appending fBodyAccMagskewness
# appending fBodyAccMagkurtosis
# appending fBodyBodyAccJerkMagmean
# appending fBodyBodyAccJerkMagstd
# appending fBodyBodyAccJerkMagmad
# appending fBodyBodyAccJerkMagmax
# appending fBodyBodyAccJerkMagmin
# appending fBodyBodyAccJerkMagsma
# appending fBodyBodyAccJerkMagenergy
# appending fBodyBodyAccJerkMagiqr
# appending fBodyBodyAccJerkMagentropy
# appending fBodyBodyAccJerkMagmaxInds
# appending fBodyBodyAccJerkMagmeanFreq
# appending fBodyBodyAccJerkMagskewness
# appending fBodyBodyAccJerkMagkurtosis
# appending fBodyBodyGyroMagmean
# appending fBodyBodyGyroMagstd
# appending fBodyBodyGyroMagmad
# appending fBodyBodyGyroMagmax
# appending fBodyBodyGyroMagmin
# appending fBodyBodyGyroMagsma
# appending fBodyBodyGyroMagenergy
# appending fBodyBodyGyroMagiqr
# appending fBodyBodyGyroMagentropy
# appending fBodyBodyGyroMagmaxInds
# appending fBodyBodyGyroMagmeanFreq
# appending fBodyBodyGyroMagskewness
# appending fBodyBodyGyroMagkurtosis
# appending fBodyBodyGyroJerkMagmean
# appending fBodyBodyGyroJerkMagstd
# appending fBodyBodyGyroJerkMagmad
# appending fBodyBodyGyroJerkMagmax
# appending fBodyBodyGyroJerkMagmin
# appending fBodyBodyGyroJerkMagsma
# appending fBodyBodyGyroJerkMagenergy
# appending fBodyBodyGyroJerkMagiqr
# appending fBodyBodyGyroJerkMagentropy
# appending fBodyBodyGyroJerkMagmaxInds
# appending fBodyBodyGyroJerkMagmeanFreq
# appending fBodyBodyGyroJerkMagskewness
# appending fBodyBodyGyroJerkMagkurtosis
# appending angletBodyAccMeangravity
# appending angletBodyAccJerkMeangravityMean
# appending angletBodyGyroMeangravityMean
# appending angletBodyGyroJerkMeangravityMean
# appending angleXgravityMean
# appending angleYgravityMean
# appending angleZgravityMean
# appending subjectid
# appending activity
# appending activityname

# %%
traindf.columns = [newcols]
traindf.columns
# Out:
# MultiIndex([(                    'tBodyAccmeanX',),
#             (                    'tBodyAccmeanY',),
#             (                    'tBodyAccmeanZ',),
#             (                     'tBodyAccstdX',),
#             (                     'tBodyAccstdY',),
#             (                     'tBodyAccstdZ',),
#             (                     'tBodyAccmadX',),
#             (                     'tBodyAccmadY',),
#             (                     'tBodyAccmadZ',),
#             (                     'tBodyAccmaxX',),
#             ...
#             (         'angletBodyAccMeangravity',),
#             ( 'angletBodyAccJerkMeangravityMean',),
#             (    'angletBodyGyroMeangravityMean',),
#             ('angletBodyGyroJerkMeangravityMean',),
#             (                'angleXgravityMean',),
#             (                'angleYgravityMean',),
#             (                'angleZgravityMean',),
#             (                        'subjectid',),
#             (                         'activity',),
#             (                     'activityname',)],
#            length=564)

# %%
testdf.columns = [newcols]
testdf.columns
# Out:
# MultiIndex([(                    'tBodyAccmeanX',),
#             (                    'tBodyAccmeanY',),
#             (                    'tBodyAccmeanZ',),
#             (                     'tBodyAccstdX',),
#             (                     'tBodyAccstdY',),
#             (                     'tBodyAccstdZ',),
#             (                     'tBodyAccmadX',),
#             (                     'tBodyAccmadY',),
#             (                     'tBodyAccmadZ',),
#             (                     'tBodyAccmaxX',),
#             ...
#             (         'angletBodyAccMeangravity',),
#             ( 'angletBodyAccJerkMeangravityMean',),
#             (    'angletBodyGyroMeangravityMean',),
#             ('angletBodyGyroJerkMeangravityMean',),
#             (                'angleXgravityMean',),
#             (                'angleYgravityMean',),
#             (                'angleZgravityMean',),
#             (                        'subjectid',),
#             (                         'activity',),
#             (                     'activityname',)],
#            length=564)

# %%
#Compile & save Train/Test DF to CSV files

traindf.to_csv(r'C:\Users\adity\har', index=False)
testdf.to_csv(r'C:\Users\adity\har', index=False)
# Out:
#      tBodyAccmeanX tBodyAccmeanY tBodyAccmeanZ tBodyAccstdX tBodyAccstdY  \
# 0         0.288585     -0.020294     -0.132905    -0.995279    -0.983111
# 1         0.278419     -0.016411     -0.123520    -0.998245    -0.975300
# 2         0.279653     -0.019467     -0.113462    -0.995380    -0.967187
# 3         0.279174     -0.026201     -0.123283    -0.996091    -0.983403
# 4         0.276629     -0.016570     -0.115362    -0.998139    -0.980817
# ...            ...           ...           ...          ...          ...
# 7347      0.299665     -0.057193     -0.181233    -0.195387     0.039905
# 7348      0.273853     -0.007749     -0.147468    -0.235309     0.004816
# 7349      0.273387     -0.017011     -0.045022    -0.218218    -0.103822
# 7350      0.289654     -0.018843     -0.158281    -0.219139    -0.111412
# 7351      0.351503     -0.012423     -0.203867    -0.269270    -0.087212
#
#      tBodyAccstdZ tBodyAccmadX tBodyAccmadY tBodyAccmadZ tBodyAccmaxX  ...  \
# 0       -0.913526    -0.995112    -0.983185    -0.923527    -0.934724  ...
# 1       -0.960322    -0.998807    -0.974914    -0.957686    -0.943068  ...
# 2       -0.978944    -0.996520    -0.963668    -0.977469    -0.938692  ...
# 3       -0.990675    -0.997099    -0.982750    -0.989302    -0.938692  ...
# 4       -0.990482    -0.998321    -0.979672    -0.990441    -0.942469  ...
# ...           ...          ...          ...          ...          ...  ...
# 7347     0.077078    -0.282301     0.043616     0.060410     0.210795  ...
# 7348     0.059280    -0.322552    -0.029456     0.080585     0.117440  ...
# 7349     0.274533    -0.304515    -0.098913     0.332584     0.043999  ...
# 7350     0.268893    -0.310487    -0.068200     0.319473     0.101702  ...
# 7351     0.177404    -0.377404    -0.038678     0.229430     0.269013  ...
#
#      angletBodyAccMeangravity angletBodyAccJerkMeangravityMean  \
# 0                   -0.112754                         0.030400
# 1                    0.053477                        -0.007435
# 2                   -0.118559                         0.177899
# 3                   -0.036788                        -0.012892
# 4                    0.123320                         0.122542
# ...                       ...                              ...
# 7347                -0.190437                         0.829718
# 7348                 0.064907                         0.875679
# 7349                 0.052806                        -0.266724
# 7350                -0.101360                         0.700740
# 7351                -0.280088                        -0.007739
#
#      angletBodyGyroMeangravityMean angletBodyGyroJerkMeangravityMean  \
# 0                        -0.464761                         -0.018446
# 1                        -0.732626                          0.703511
# 2                         0.100699                          0.808529
# 3                         0.640011                         -0.485366
# 4                         0.693578                         -0.615971
# ...                            ...                               ...
# 7347                      0.206972                         -0.425619
# 7348                     -0.879033                          0.400219
# 7349                      0.864404                          0.701169
# 7350                      0.936674                         -0.589479
# 7351                     -0.056088                         -0.616956
#
#      angleXgravityMean angleYgravityMean angleZgravityMean subjectid activity  \
# 0            -0.841247          0.179941         -0.058627         1        5
# 1            -0.844788          0.180289         -0.054317         1        5
# 2            -0.848933          0.180637         -0.049118         1        5
# 3            -0.848649          0.181935         -0.047663         1        5
# 4            -0.847865          0.185151         -0.043892         1        5
# ...                ...               ...               ...       ...      ...
# 7347         -0.791883          0.238604          0.049819        30        2
# 7348         -0.771840          0.252676          0.050053        30        2
# 7349         -0.779133          0.249145          0.040811        30        2
# 7350         -0.785181          0.246432          0.025339        30        2
# 7351         -0.783267          0.246809          0.036695        30        2
#
#           activityname
# 0             STANDING
# 1             STANDING
# 2             STANDING
# 3             STANDING
# 4             STANDING
# ...                ...
# 7347  WALKING_UPSTAIRS
# 7348  WALKING_UPSTAIRS
# 7349  WALKING_UPSTAIRS
# 7350  WALKING_UPSTAIRS
# 7351  WALKING_UPSTAIRS
#
# [7352 rows x 564 columns]

# %%
xtrain = (traindf.drop(['subjectid','activity','activityname'], axis=1)).values
ytrain = traindf['activity'].values

xtest = (testdf.drop(['subjectid','activity','activityname'], axis=1)).values
ytest = testdf['activity'].values

# %%
print(xtrain)
print(xtrain.shape)
# Out:
# [[ 0.28858451 -0.02029417 -0.13290514 ... -0.84124676  0.17994061
#   -0.05862692]
#  [ 0.27841883 -0.01641057 -0.12352019 ... -0.8447876   0.18028889
#   -0.05431672]
#  [ 0.27965306 -0.01946716 -0.11346169 ... -0.84893347  0.18063731
#   -0.04911782]
#  ...
#  [ 0.27338737 -0.01701062 -0.04502183 ... -0.77913261  0.24914484
#    0.04081119]
#  [ 0.28965416 -0.01884304 -0.15828059 ... -0.78518142  0.24643223
#    0.02533948]
#  [ 0.35150347 -0.01242312 -0.20386717 ... -0.78326693  0.24680852
#    0.03669484]]
# (7352, 561)

# %%
print(ytrain)
print(ytrain.shape)
# Out:
# [[5]
#  [5]
#  [5]
#  ...
#  [2]
#  [2]
#  [2]]
# (7352, 1)

# %%
print(xtest)
print(xtest.shape)
# Out:
# [[ 0.25717778 -0.02328523 -0.01465376 ... -0.72000927  0.27680104
#   -0.0579783 ]
#  [ 0.28602671 -0.01316336 -0.11908252 ... -0.69809082  0.28134292
#   -0.08389801]
#  [ 0.27548482 -0.02605042 -0.11815167 ... -0.70277146  0.28008303
#   -0.0793462 ]
#  ...
#  [ 0.34996609  0.03007744 -0.11578796 ... -0.65535684  0.27447878
#    0.18118355]
#  [ 0.23759383  0.01846687 -0.09649893 ... -0.65971859  0.26478161
#    0.18756291]
#  [ 0.15362719 -0.01843651 -0.13701846 ... -0.66008023  0.26393619
#    0.1881034 ]]
# (2947, 561)

# %%
print(ytest)
print(ytest.shape)
# Out:
# [[5]
#  [5]
#  [5]
#  ...
#  [2]
#  [2]
#  [2]]
# (2947, 1)

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(multi_class='ovr')
classifier.fit(xtrain, ytrain)
# Out:
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(multi_class='ovr')

# %%
#predict results on testing independent features
ypred = classifier.predict(xtest)
print(ypred)
# Out:
# [5 5 5 ... 2 2 2]

# %%
#accuracy of logictic regression
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of LOGISTIC REGRESSON {acc*100}%')
# Out:
# [[494   0   2   0   0   0]
#  [ 26 445   0   0   0   0]
#  [  4   9 407   0   0   0]
#  [  0   3   0 437  51   0]
#  [  2   0   0  13 517   0]
#  [  0   0   0   0   0 537]]
# Accuracy of LOGISTIC REGRESSON 96.26739056667797%

# %%
#Naive bayes

from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(xtrain,ytrain)
# Out:
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
#predict results on testing independent features
ypred = classifier.predict(xtest)
print(ypred)
# Out:
# [5 5 5 ... 2 2 2]

# %%
#accuracy of naive bayes
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of NAIVE BAYES {acc*100}%')
# Out:
# [[416  38  42   0   0   0]
#  [  9 451  11   0   0   0]
#  [ 80  83 257   0   0   0]
#  [  0   7   0 368 111   5]
#  [  0  15   0  54 455   8]
#  [  0   3   0 211   0 323]]
# Accuracy of NAIVE BAYES 77.02748557855446%

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
classifier.fit(xtrain, ytrain)
# Out:
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
#predict results on testing independent features
ypred = classifier.predict(xtest)
print(ypred)
# Out:
# [5 5 5 ... 2 2 1]

# %%
#accuracy of knn
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of KNN {acc*100}%')
# Out:
# [[485   2   9   0   0   0]
#  [ 40 424   7   0   0   0]
#  [ 45  45 330   0   0   0]
#  [  0   3   0 389  99   0]
#  [  0   0   0  37 495   0]
#  [  0   0   0   2   1 534]]
# Accuracy of KNN 90.15948422124194%

# %%
#Support Vector Classifier --> SVC (WITH KERNEL TRICK kernel='rbf' for NON LINEARLY SEPERABLE DATA) (NORMAL KERNEL WE SHALL USE kernel='linear' it's for linearly seperable data)
from sklearn.svm import SVC
#radial basis function KERNEL
classifier = SVC(kernel='rbf', random_state=0)
classifier.fit(xtrain, ytrain)
# Out:
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(random_state=0)

# %%
#predict results on testing independent features
ypred = classifier.predict(xtest)
print(ypred)
# Out:
# [5 5 5 ... 2 2 2]

# %%
#accuracy of svc
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of SVC-RBF {acc*100}%')
# Out:
# [[488   5   3   0   0   0]
#  [ 20 451   0   0   0   0]
#  [ 10  26 384   0   0   0]
#  [  0   2   0 438  51   0]
#  [  0   0   0  29 503   0]
#  [  0   0   0   0   0 537]]
# Accuracy of SVC-RBF 95.04580929759076%

# %%
#SVC with linear kernel
from sklearn.svm import SVC

classifier = SVC(kernel='linear', random_state=0)
classifier.fit(xtrain, ytrain)
# Out:
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear', random_state=0)

# %%
#predict results on testing independent features
ypred = classifier.predict(xtest)
print(ypred)
# Out:
# [5 5 5 ... 2 2 2]

# %%
#accuracy of svc
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of SVC-LINEAR {acc*100}%')
# Out:
# [[492   1   3   0   0   0]
#  [ 18 451   2   0   0   0]
#  [  4   6 410   0   0   0]
#  [  0   2   0 435  54   0]
#  [  0   0   0  16 516   0]
#  [  0   0   0   0   0 537]]
# Accuracy of SVC-LINEAR 96.40312181879878%

# %%
#Decision Trees Classifier (CART --> Classification & regression trees)
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
#predict results on testing independent features
ypred = classifier.predict(xtest)
print(ypred)
# Out:
# [5 5 5 ... 2 1 2]

# %%
#accuracy of Decision trees
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of D-Trees {acc*100}%')
# Out:
# [[455  22  19   0   0   0]
#  [ 67 368  36   0   0   0]
#  [ 23  45 352   0   0   0]
#  [  0   0   0 375 116   0]
#  [  0   0   0  78 454   0]
#  [  0   0   0   0   0 537]]
# Accuracy of D-Trees 86.22327790973871%

# %%
#Gradient Boosted Decision Trees
from sklearn.ensemble import GradientBoostingClassifier
classifier = GradientBoostingClassifier(n_estimators=100, max_depth=3, learning_rate=0.1)
classifier.fit(xtrain,ytrain)
# Out:
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier()

# %%
ypred = classifier.predict(xtest)
ypred
# Out:
# array([5, 5, 5, ..., 2, 2, 2], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of GDBoost D-Trees {acc*100}%')
# Out:
# [[486   5   5   0   0   0]
#  [ 25 440   5   1   0   0]
#  [  8  25 386   0   1   0]
#  [  0   3   0 416  72   0]
#  [  0   0   0  32 500   0]
#  [  0   0   0   0   0 537]]
# Accuracy of GDBoost D-Trees 93.82422802850357%

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100, max_depth=20)
classifier.fit(xtrain,ytrain)
# Out:
# D:\Anaconda\envs\ml\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(max_depth=20)

# %%
#Predicting results on test set
ypred = classifier.predict(xtest)
ypred
# Out:
# array([5, 5, 5, ..., 2, 2, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest, ypred)
print(cm)
acc = accuracy_score(ytest,ypred)
print(f'Accuracy of GDBoost D-Trees {acc*100}%')
# Out:
# [[480   6  10   0   0   0]
#  [ 40 425   6   0   0   0]
#  [ 26  46 348   0   0   0]
#  [  0   0   0 437  54   0]
#  [  0   0   0  44 488   0]
#  [  0   0   0   0   0 537]]
# Accuracy of GDBoost D-Trees 92.12758737699356%
